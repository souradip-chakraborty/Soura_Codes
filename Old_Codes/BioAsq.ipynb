# %%
import pandas as pd
import json
import numpy as np

# %%
df = pd.read_json('/Users/s0c02nj/Downloads/BioASQ-67b-15Oct2019/BioASQ-7b/train/Full-Abstract/BioASQ-train-factoid-7b-full-annotated.json')

# %%
df['data'][0]
# Out:
# {'paragraphs': [{'qas': [{'id': '56bc751eac7ad10019000013_001',
#      'question': 'Name synonym of Acrokeratosis paraneoplastica.',
#      'answers': [{'text': 'Bazex syndrome', 'answer_start': 31}]}],
# ...
