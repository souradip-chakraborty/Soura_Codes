# %%
from sklearn.linear_model import Ridge
import numpy as np
import sklearn.datasets
from sklearn import linear_model
import sklearn.cross_validation
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn import ensemble
import time
import random
import cv2

# %%
def get_list_image(imagepath): 
    import os
    folder_path=imagepath
    image_list=[]
    for filename in os.listdir(folder_path):
        if(filename.endswith('.jpg') | filename.endswith('.jpeg') | filename.endswith('.png')):
        #it will open the filename
            #f=open(folder_path + '/' + filename)
            #print f
            image=cv2.imread(folder_path + '/' + filename)
            
            #image=cv2.imread(os.path.join(folder_path,filename))
            image_list.append(image)
    return image_list

# %%
#np.shape(train_jar[6])
jar='/Users/s0c01xa/Documents/Jar Images'
non_jar='/Users/s0c01xa/Documents/Non Jar images'

train_jar=get_list_image(jar)
train_nonjar=get_list_image(non_jar)

# %%
#Vertical Gradient

# %%
a=[[1,0,-1],[1,0,-1],[1,0,-1]]
plt.imshow(a)
plt.show()

# %%
#Horizontal Gradient

# %%
#Performing Convolution on Images with the following and checking the sense.

# %%
#plt.imshow(train_jar[0])
image1=cv2.imread('/Users/s0c01xa/Desktop/Gradients and convol.jpeg')
plt.imshow(image1)
plt.show()
image=cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# %%
np.shape(image)
#image[5,2]
# Out:
# (350, 538)

# %% [markdown]
# # HORIZONTAL CONVOLUTION

# %%
hor_kernel=[[1,1,1],[0,0,0],[-1,-1,-1]]
plt.imshow(hor_kernel)
plt.show()

# %%
from scipy import signal
#conv_img_horizontal=signal.convolve2d(image, hor_kernel, mode='full', boundary='fill', fillvalue=0)
conv_img_horizontal=signal.convolve2d(image, hor_kernel, mode='full', boundary='fill', fillvalue=0)

plt.imshow(conv_img_horizontal)
plt.show()
