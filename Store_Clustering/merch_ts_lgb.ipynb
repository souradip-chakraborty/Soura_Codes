# %%
import pandas as pd
import numpy as np

import holidays
from collections import Counter
#from datetime import timedelta, date
import statsmodels
from sklearn.preprocessing import LabelEncoder
from statsmodels.formula.api import ols
from scipy import stats
import seaborn as sns

from tqdm import tqdm
import itertools

from scipy.spatial.distance import euclidean
import time
#%matplotlib inline
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.holtwinters import ExponentialSmoothing
# Out:
# /Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
x_train = pd.read_csv('/Users/s0c02nj/Desktop/merch_ts/mode_imp_all.csv')
x_test =  pd.read_csv('/Users/s0c02nj/Desktop/merch_ts/test_data_date.csv')

# %%
x_train['ind'] = 'tr'
x_test['ind'] = 'te'

# %%
df_train = x_train[['mds_fam_id','dc_nbr','date','dept_nbr','vendor_nm',
                   'unit_cost','corp_retail_price','ind']]

y_train = x_train[['actual_packs_order']]


df_test = x_test[['mds_fam_id','dc_nbr','date','dept_nbr','vendor_nm',
                   'unit_cost','corp_retail_price','ind']]

# %%
df_total = pd.concat([df_train,df_test])

# %%
df_total['date'] = pd.to_datetime(df_total['date'])

df_total['week'] =  df_total['date'].dt.week
df_total['year'] =  df_total['date'].dt.year
df_total['month'] = df_total['date'].dt.month

# %%
df_total['mds_dc'] = df_total['mds_fam_id'].astype(str) + '_' + df_total['dc_nbr'].astype(str)
df_total['dept_dc'] = df_total['dc_nbr'].astype(str) + '_' + df_total['dept_nbr'].astype(str)
df_total['dept_mds'] = df_total['mds_fam_id'].astype(str) + '_' + df_total['dept_nbr'].astype(str)

# %%
df_total['mds_week'] = df_total['mds_fam_id'].astype(str) + '_' + df_total['week'].astype(str)

# %%
y_p1 = list(y_train['actual_packs_order'].values)
y_p2 = [0]*x_test.shape[0]
y_p = y_p1 + y_p2

df_total['order'] = y_p

# %%
df_train1 = df_total[df_total['ind'] == 'tr']

# %%
cat_cols = ['mds_fam_id',
             'dc_nbr',
             'dept_nbr',
             'week',
             'year',
             'month',
             'mds_dc',
             'dept_dc',
             'dept_mds',
             'mds_week']

# %%
for i,col in tqdm(enumerate(cat_cols)):
    med = df_train1.groupby(col)['order'].median()
    df_total[str(col)+'count'+'1'] = df_total[col].map(med)
# Out:
# 10it [00:00, 127.39it/s]

# %%
df_total1 = df_total.sort_values(by=['mds_dc','date'])

# %%
df_total1.index = range(0,len(df_total1))

# %%
#df_total1
unique_md_dc = list(df_total1['mds_dc'].unique())

# %%
df_total1.columns
# Out:
# Index(['mds_fam_id', 'dc_nbr', 'date', 'dept_nbr', 'vendor_nm', 'unit_cost',
#        'corp_retail_price', 'ind', 'week', 'year', 'month', 'mds_dc',
#        'dept_dc', 'dept_mds', 'mds_week', 'order', 'mds_fam_idcount1',
#        'dc_nbrcount1', 'dept_nbrcount1', 'weekcount1', 'yearcount1',
#        'monthcount1', 'mds_dccount1', 'dept_dccount1', 'dept_mdscount1',
#        'mds_weekcount1'],
#       dtype='object')

# %%
reqd_cols = ['mds_fam_id',
             'dc_nbr',
             'date',
             'dept_nbr',
             'ind',
             'week',
             'year',
             'month',
             'mds_dc',
             'dept_dc',
             'dept_mds',
             'mds_week',
             'mds_fam_idcount1',
             'dc_nbrcount1',
             'dept_nbrcount1',
             'weekcount1',
             'yearcount1',
             'monthcount1',
             'mds_dccount1',
             'dept_dccount1',
             'dept_mdscount1',
             'mds_weekcount1',
             'order']

# %%
df_total1 = df_total1[reqd_cols]

# %%
le = LabelEncoder()
le_cols = ['mds_dc','dept_dc','dept_mds','mds_week']

for col in tqdm(le_cols):
    le = LabelEncoder()
    #le = le.fit(df_total1[col])
    df_total1[col] = le.fit_transform(df_total1[col])
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 64.90it/s]

# %%
df_train_v1 = df_total1[df_total1['ind'] == 'tr']
df_test_v1 =  df_total1[df_total1['ind'] == 'te']

# %%
unique_md_dc = list(df_total1['mds_dc'].unique())

# %%
df_comb_tr = pd.DataFrame()
df_comb_val = pd.DataFrame()


x_t1 = df_train_v1

for u_id in tqdm(unique_md_dc) :
    
    #Groupby
    df_temp1 = x_t1[x_t1['mds_dc'] == u_id].sort_values(by='date')
    df_temp1 = df_temp1.drop(['ind','date'],axis=1)
    
    df_temp1.index = range(0,len(df_temp1))
    
    #Train-test split
    df_temp_tr = df_temp1[0:int(df_temp1.shape[0]*0.85)]
    df_temp_val = df_temp1[int(df_temp1.shape[0]*0.15):]
    #print (df_temp.head())
    
    #Appending
    df_comb_tr =  pd.concat([df_comb_tr,df_temp_tr],axis=0)
    df_comb_val = pd.concat([df_comb_val,df_temp_val],axis=0)
# Out:
# 100%|██████████| 442/442 [00:09<00:00, 46.07it/s]

# %%
x_train = df_comb_tr.drop(['order'],axis=1)
y_train = df_comb_tr['order']

x_val = df_comb_val.drop(['order'],axis=1)
y_val = df_comb_val['order']

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'max_depth': 10, 
    'learning_rate': 0.1,
    'verbose': 1, 
    }

# %%
n_estimators = 1000

# %%
d_train = lgb.Dataset(x_train, label = y_train)
d_valid = lgb.Dataset(x_val, label = y_val)

# %%
model = lgb.train(params,
                  d_train, 
                  n_estimators,
                  valid_sets = [d_train, d_valid],
                  early_stopping_rounds=500,
                  verbose_eval=1)
# Out:
# [1]	training's rmse: 221.318	valid_1's rmse: 205.215
# Training until validation scores don't improve for 500 rounds.
# [2]	training's rmse: 207.577	valid_1's rmse: 193.004
# [3]	training's rmse: 195.613	valid_1's rmse: 182.048
# [4]	training's rmse: 185.042	valid_1's rmse: 172.653
# [5]	training's rmse: 175.755	valid_1's rmse: 164.678
# [6]	training's rmse: 168.023	valid_1's rmse: 157.938
# [7]	training's rmse: 161.679	valid_1's rmse: 152.134
# [8]	training's rmse: 155.824	valid_1's rmse: 147.18
# [9]	training's rmse: 150.596	valid_1's rmse: 142.819
# [10]	training's rmse: 146.4	valid_1's rmse: 139.191
# [11]	training's rmse: 142.415	valid_1's rmse: 136.022
# [12]	training's rmse: 139.316	valid_1's rmse: 133.325
# [13]	training's rmse: 136.273	valid_1's rmse: 130.977
# [14]	training's rmse: 133.465	valid_1's rmse: 128.844
# [15]	training's rmse: 130.865	valid_1's rmse: 126.819
# [16]	training's rmse: 129.108	valid_1's rmse: 125.412
# [69]	training's rmse: 102.282	valid_1's rmse: 104.953
# [70]	training's rmse: 101.975	valid_1's rmse: 104.77
# [71]	training's rmse: 101.768	valid_1's rmse: 104.646
# [72]	training's rmse: 101.715	valid_1's rmse: 104.61
# [73]	training's rmse: 101.656	valid_1's rmse: 104.575
# [74]	training's rmse: 101.492	valid_1's rmse: 104.483
# [75]	training's rmse: 101.221	valid_1's rmse: 104.292
# [76]	training's rmse: 101.121	valid_1's rmse: 104.242
# [77]	training's rmse: 100.887	valid_1's rmse: 104.094
# [78]	training's rmse: 100.827	valid_1's rmse: 104.046
# [79]	training's rmse: 100.569	valid_1's rmse: 103.837
# [80]	training's rmse: 100.511	valid_1's rmse: 103.791
# [81]	training's rmse: 100.256	valid_1's rmse: 103.582
# [82]	training's rmse: 100.086	valid_1's rmse: 103.489
# [83]	training's rmse: 100.022	valid_1's rmse: 103.435
# [84]	training's rmse: 99.9551	valid_1's rmse: 103.38
# [85]	training's rmse: 99.877	valid_1's rmse: 103.31
# [86]	training's rmse: 99.6396	valid_1's rmse: 103.2
# [87]	training's rmse: 99.5869	valid_1's rmse: 103.159
# [88]	training's rmse: 99.5025	valid_1's rmse: 103.126
# [89]	training's rmse: 99.2615	valid_1's rmse: 102.933
# [90]	training's rmse: 99.1562	valid_1's rmse: 102.834
# [91]	training's rmse: 98.9126	valid_1's rmse: 102.658
# [92]	training's rmse: 98.8052	valid_1's rmse: 102.609
# [93]	training's rmse: 98.7242	valid_1's rmse: 102.549
# [94]	training's rmse: 98.5796	valid_1's rmse: 102.472
# [95]	training's rmse: 98.4825	valid_1's rmse: 102.405
# [96]	training's rmse: 98.3177	valid_1's rmse: 102.252
# [97]	training's rmse: 98.1739	valid_1's rmse: 102.188
# [98]	training's rmse: 98.1217	valid_1's rmse: 102.146
# [99]	training's rmse: 98.0702	valid_1's rmse: 102.101
# [100]	training's rmse: 98.0286	valid_1's rmse: 102.068
# [101]	training's rmse: 97.859	valid_1's rmse: 101.918
# [102]	training's rmse: 97.652	valid_1's rmse: 101.779
# [103]	training's rmse: 97.5767	valid_1's rmse: 101.736
# [104]	training's rmse: 97.4281	valid_1's rmse: 101.646
# [105]	training's rmse: 97.2422	valid_1's rmse: 101.442
# [106]	training's rmse: 97.1207	valid_1's rmse: 101.329
# [107]	training's rmse: 97.0482	valid_1's rmse: 101.285
# [108]	training's rmse: 96.9927	valid_1's rmse: 101.241
# [109]	training's rmse: 96.8424	valid_1's rmse: 101.103
# [110]	training's rmse: 96.8186	valid_1's rmse: 101.084
# [111]	training's rmse: 96.6951	valid_1's rmse: 100.993
# [112]	training's rmse: 96.6523	valid_1's rmse: 100.958
# [113]	training's rmse: 96.5303	valid_1's rmse: 100.889
# [114]	training's rmse: 96.4203	valid_1's rmse: 100.764
# [115]	training's rmse: 96.4023	valid_1's rmse: 100.748
# [116]	training's rmse: 96.3369	valid_1's rmse: 100.689
# [117]	training's rmse: 96.2852	valid_1's rmse: 100.629
# [118]	training's rmse: 96.0506	valid_1's rmse: 100.462
# [119]	training's rmse: 95.9074	valid_1's rmse: 100.371
# [120]	training's rmse: 95.8363	valid_1's rmse: 100.302
# [121]	training's rmse: 95.7551	valid_1's rmse: 100.205
# [122]	training's rmse: 95.7055	valid_1's rmse: 100.167
# [123]	training's rmse: 95.6496	valid_1's rmse: 100.119
# [124]	training's rmse: 95.6035	valid_1's rmse: 100.072
# [125]	training's rmse: 95.5232	valid_1's rmse: 100.01
# [126]	training's rmse: 95.4557	valid_1's rmse: 99.9394
# [127]	training's rmse: 95.4351	valid_1's rmse: 99.9243
# [128]	training's rmse: 95.391	valid_1's rmse: 99.9058
# [129]	training's rmse: 95.3084	valid_1's rmse: 99.849
# [130]	training's rmse: 95.2451	valid_1's rmse: 99.8043
# [131]	training's rmse: 95.2291	valid_1's rmse: 99.793
# [132]	training's rmse: 95.0704	valid_1's rmse: 99.6995
# [133]	training's rmse: 94.9815	valid_1's rmse: 99.6196
# [134]	training's rmse: 94.9367	valid_1's rmse: 99.5899
# [135]	training's rmse: 94.8984	valid_1's rmse: 99.5529
# [136]	training's rmse: 94.8543	valid_1's rmse: 99.5258
# [137]	training's rmse: 94.6603	valid_1's rmse: 99.3231
# [138]	training's rmse: 94.5653	valid_1's rmse: 99.2755
# [139]	training's rmse: 94.53	valid_1's rmse: 99.2457
# [140]	training's rmse: 94.3847	valid_1's rmse: 99.1778
# [141]	training's rmse: 94.2983	valid_1's rmse: 99.1244
# [142]	training's rmse: 94.2663	valid_1's rmse: 99.0923
# [143]	training's rmse: 94.1782	valid_1's rmse: 99.0427
# [144]	training's rmse: 94.1434	valid_1's rmse: 99.0222
# [145]	training's rmse: 94.0963	valid_1's rmse: 98.9788
# [146]	training's rmse: 94.0242	valid_1's rmse: 98.9525
# [147]	training's rmse: 93.9572	valid_1's rmse: 98.901
# [148]	training's rmse: 93.867	valid_1's rmse: 98.8802
# [149]	training's rmse: 93.7891	valid_1's rmse: 98.8514
# [150]	training's rmse: 93.7057	valid_1's rmse: 98.8048
# [151]	training's rmse: 93.5769	valid_1's rmse: 98.7145
# [152]	training's rmse: 93.5155	valid_1's rmse: 98.6929
# [153]	training's rmse: 93.4734	valid_1's rmse: 98.6588
# [154]	training's rmse: 93.4214	valid_1's rmse: 98.6239
# [155]	training's rmse: 93.2197	valid_1's rmse: 98.527
# [156]	training's rmse: 93.1727	valid_1's rmse: 98.4878
# [157]	training's rmse: 93.1423	valid_1's rmse: 98.4596
# [158]	training's rmse: 93.1009	valid_1's rmse: 98.4213
# [159]	training's rmse: 93.0232	valid_1's rmse: 98.3528
# [160]	training's rmse: 92.9765	valid_1's rmse: 98.319
# [161]	training's rmse: 92.8497	valid_1's rmse: 98.2352
# [162]	training's rmse: 92.8123	valid_1's rmse: 98.2043
# [163]	training's rmse: 92.7255	valid_1's rmse: 98.1789
# [164]	training's rmse: 92.4848	valid_1's rmse: 98.105
# [165]	training's rmse: 92.4341	valid_1's rmse: 98.0621
# [166]	training's rmse: 92.4044	valid_1's rmse: 98.0448
# [167]	training's rmse: 92.3459	valid_1's rmse: 98.0229
# [168]	training's rmse: 92.2656	valid_1's rmse: 97.9515
# [169]	training's rmse: 92.2326	valid_1's rmse: 97.943
# [170]	training's rmse: 92.1196	valid_1's rmse: 97.8534
# [171]	training's rmse: 92.0434	valid_1's rmse: 97.794
# [172]	training's rmse: 91.9712	valid_1's rmse: 97.7802
# [173]	training's rmse: 91.9376	valid_1's rmse: 97.7531
# [174]	training's rmse: 91.9254	valid_1's rmse: 97.7451
# [175]	training's rmse: 91.8294	valid_1's rmse: 97.6974
# [176]	training's rmse: 91.6522	valid_1's rmse: 97.6709
# [177]	training's rmse: 91.6201	valid_1's rmse: 97.6451
# [178]	training's rmse: 91.5692	valid_1's rmse: 97.6166
# [179]	training's rmse: 91.5552	valid_1's rmse: 97.6014
# [180]	training's rmse: 91.5163	valid_1's rmse: 97.5681
# [181]	training's rmse: 91.3283	valid_1's rmse: 97.5502
# [182]	training's rmse: 91.3035	valid_1's rmse: 97.5288
# [183]	training's rmse: 91.2674	valid_1's rmse: 97.5012
# [184]	training's rmse: 91.2232	valid_1's rmse: 97.4613
# [185]	training's rmse: 91.0598	valid_1's rmse: 97.5143
# [186]	training's rmse: 91.0241	valid_1's rmse: 97.4819
# [187]	training's rmse: 90.9097	valid_1's rmse: 97.3986
# [188]	training's rmse: 90.8729	valid_1's rmse: 97.3659
# [189]	training's rmse: 90.8632	valid_1's rmse: 97.3593
# [190]	training's rmse: 90.702	valid_1's rmse: 97.3499
# [191]	training's rmse: 90.6641	valid_1's rmse: 97.3145
# [192]	training's rmse: 90.6359	valid_1's rmse: 97.2892
# [193]	training's rmse: 90.5971	valid_1's rmse: 97.2572
# [194]	training's rmse: 90.5535	valid_1's rmse: 97.231
# [195]	training's rmse: 90.5215	valid_1's rmse: 97.209
# [196]	training's rmse: 90.4758	valid_1's rmse: 97.1815
# [197]	training's rmse: 90.3912	valid_1's rmse: 97.1164
# [198]	training's rmse: 90.3231	valid_1's rmse: 97.0597
# [199]	training's rmse: 90.2867	valid_1's rmse: 97.0249
# [200]	training's rmse: 90.2505	valid_1's rmse: 97.0036
# [201]	training's rmse: 90.2147	valid_1's rmse: 96.978
# [202]	training's rmse: 90.057	valid_1's rmse: 97.0179
# [203]	training's rmse: 90.0248	valid_1's rmse: 96.9931
# [204]	training's rmse: 89.9192	valid_1's rmse: 96.9233
# [205]	training's rmse: 89.8907	valid_1's rmse: 96.9086
# [206]	training's rmse: 89.8585	valid_1's rmse: 96.9054
# [207]	training's rmse: 89.8039	valid_1's rmse: 96.9063
# [208]	training's rmse: 89.774	valid_1's rmse: 96.8849
# [209]	training's rmse: 89.7235	valid_1's rmse: 96.8598
# [210]	training's rmse: 89.6648	valid_1's rmse: 96.8215
# [211]	training's rmse: 89.6281	valid_1's rmse: 96.7965
# [212]	training's rmse: 89.5205	valid_1's rmse: 96.7523
# [213]	training's rmse: 89.4984	valid_1's rmse: 96.7334
# [214]	training's rmse: 89.4371	valid_1's rmse: 96.69
# [215]	training's rmse: 89.3344	valid_1's rmse: 96.6287
# [216]	training's rmse: 89.226	valid_1's rmse: 96.6345
# [217]	training's rmse: 89.1877	valid_1's rmse: 96.6145
# [218]	training's rmse: 89.1645	valid_1's rmse: 96.5977
# [219]	training's rmse: 89.0758	valid_1's rmse: 96.5947
# [220]	training's rmse: 89.0486	valid_1's rmse: 96.5769
# [221]	training's rmse: 88.9896	valid_1's rmse: 96.5536
# [222]	training's rmse: 88.8702	valid_1's rmse: 96.4918
# [223]	training's rmse: 88.7736	valid_1's rmse: 96.4361
# [224]	training's rmse: 88.6755	valid_1's rmse: 96.3657
# [225]	training's rmse: 88.6267	valid_1's rmse: 96.3369
# [226]	training's rmse: 88.5267	valid_1's rmse: 96.3128
# [227]	training's rmse: 88.4326	valid_1's rmse: 96.2409
# [228]	training's rmse: 88.3885	valid_1's rmse: 96.2136
# [229]	training's rmse: 88.3513	valid_1's rmse: 96.1781
# [230]	training's rmse: 88.3155	valid_1's rmse: 96.1529
# [231]	training's rmse: 88.2783	valid_1's rmse: 96.1333
# [232]	training's rmse: 88.2674	valid_1's rmse: 96.1237
# [233]	training's rmse: 88.1779	valid_1's rmse: 96.051
# [234]	training's rmse: 88.1375	valid_1's rmse: 96.0287
# [235]	training's rmse: 88.1041	valid_1's rmse: 95.9971
# [236]	training's rmse: 88.0837	valid_1's rmse: 95.9812
# [237]	training's rmse: 88.045	valid_1's rmse: 95.9665
# [238]	training's rmse: 88.0201	valid_1's rmse: 95.9505
# [239]	training's rmse: 87.9938	valid_1's rmse: 95.9317
# [240]	training's rmse: 87.9006	valid_1's rmse: 95.862
# [241]	training's rmse: 87.8627	valid_1's rmse: 95.8292
# [242]	training's rmse: 87.8321	valid_1's rmse: 95.8143
# [243]	training's rmse: 87.7999	valid_1's rmse: 95.7925
# [244]	training's rmse: 87.7679	valid_1's rmse: 95.767
# [245]	training's rmse: 87.7224	valid_1's rmse: 95.7244
# [246]	training's rmse: 87.696	valid_1's rmse: 95.705
# [247]	training's rmse: 87.6366	valid_1's rmse: 95.6554
# [248]	training's rmse: 87.5971	valid_1's rmse: 95.6325
# [249]	training's rmse: 87.5415	valid_1's rmse: 95.5973
# [250]	training's rmse: 87.4805	valid_1's rmse: 95.5767
# [251]	training's rmse: 87.4031	valid_1's rmse: 95.5367
# [252]	training's rmse: 87.3757	valid_1's rmse: 95.5168
# [253]	training's rmse: 87.3261	valid_1's rmse: 95.4946
# [254]	training's rmse: 87.2746	valid_1's rmse: 95.4482
# [255]	training's rmse: 87.2432	valid_1's rmse: 95.4261
# [256]	training's rmse: 87.1987	valid_1's rmse: 95.4005
# [257]	training's rmse: 87.1744	valid_1's rmse: 95.3838
# [258]	training's rmse: 87.114	valid_1's rmse: 95.349
# [259]	training's rmse: 87.0368	valid_1's rmse: 95.2819
# [260]	training's rmse: 86.9748	valid_1's rmse: 95.2319
# [261]	training's rmse: 86.9491	valid_1's rmse: 95.1977
# [262]	training's rmse: 86.9242	valid_1's rmse: 95.1739
# [263]	training's rmse: 86.8627	valid_1's rmse: 95.1567
# [264]	training's rmse: 86.761	valid_1's rmse: 95.1568
# [265]	training's rmse: 86.7188	valid_1's rmse: 95.127
# [413]	training's rmse: 81.6319	valid_1's rmse: 92.6428
# [414]	training's rmse: 81.582	valid_1's rmse: 92.6087
# [415]	training's rmse: 81.567	valid_1's rmse: 92.6
# [416]	training's rmse: 81.5506	valid_1's rmse: 92.589
# [417]	training's rmse: 81.5261	valid_1's rmse: 92.5667
# [418]	training's rmse: 81.5123	valid_1's rmse: 92.5652
# [419]	training's rmse: 81.5033	valid_1's rmse: 92.5589
# [420]	training's rmse: 81.4903	valid_1's rmse: 92.5509
# [421]	training's rmse: 81.4481	valid_1's rmse: 92.5359
# [422]	training's rmse: 81.4195	valid_1's rmse: 92.5173
# [423]	training's rmse: 81.3992	valid_1's rmse: 92.5084
# [424]	training's rmse: 81.352	valid_1's rmse: 92.4689
# [425]	training's rmse: 81.3336	valid_1's rmse: 92.4484
# [426]	training's rmse: 81.2984	valid_1's rmse: 92.4349
# [427]	training's rmse: 81.2584	valid_1's rmse: 92.4117
# [428]	training's rmse: 81.2429	valid_1's rmse: 92.4016
# [429]	training's rmse: 81.2248	valid_1's rmse: 92.3935
# [430]	training's rmse: 81.2081	valid_1's rmse: 92.3847
# [431]	training's rmse: 81.1744	valid_1's rmse: 92.3549
# [432]	training's rmse: 81.1184	valid_1's rmse: 92.3162
# [433]	training's rmse: 81.1059	valid_1's rmse: 92.3067
# [434]	training's rmse: 81.1015	valid_1's rmse: 92.3039
# [435]	training's rmse: 81.0635	valid_1's rmse: 92.2781
# [436]	training's rmse: 81.0557	valid_1's rmse: 92.2774
# [437]	training's rmse: 81.0298	valid_1's rmse: 92.2509
# [438]	training's rmse: 80.9622	valid_1's rmse: 92.213
# [439]	training's rmse: 80.9087	valid_1's rmse: 92.1936
# [440]	training's rmse: 80.8692	valid_1's rmse: 92.1616
# [441]	training's rmse: 80.8138	valid_1's rmse: 92.1383
# [442]	training's rmse: 80.7784	valid_1's rmse: 92.1086
# [443]	training's rmse: 80.7695	valid_1's rmse: 92.1072
# [444]	training's rmse: 80.7543	valid_1's rmse: 92.1097
# [445]	training's rmse: 80.7385	valid_1's rmse: 92.0983
# [446]	training's rmse: 80.7307	valid_1's rmse: 92.0936
# [447]	training's rmse: 80.7231	valid_1's rmse: 92.0896
# [448]	training's rmse: 80.7044	valid_1's rmse: 92.0793
# [449]	training's rmse: 80.6712	valid_1's rmse: 92.0593
# [450]	training's rmse: 80.642	valid_1's rmse: 92.036
# [451]	training's rmse: 80.6204	valid_1's rmse: 92.0159
# [452]	training's rmse: 80.5699	valid_1's rmse: 92.0025
# [453]	training's rmse: 80.5435	valid_1's rmse: 91.9848
# [454]	training's rmse: 80.5264	valid_1's rmse: 91.9752
# [455]	training's rmse: 80.511	valid_1's rmse: 91.9692
# [456]	training's rmse: 80.4711	valid_1's rmse: 91.9409
# [457]	training's rmse: 80.4411	valid_1's rmse: 91.9197
# [458]	training's rmse: 80.4172	valid_1's rmse: 91.903
# [459]	training's rmse: 80.3511	valid_1's rmse: 91.8716
# [460]	training's rmse: 80.3243	valid_1's rmse: 91.8584
# [510]	training's rmse: 78.9836	valid_1's rmse: 91.0013
# [511]	training's rmse: 78.9466	valid_1's rmse: 90.9853
# [512]	training's rmse: 78.9284	valid_1's rmse: 90.9682
# [513]	training's rmse: 78.9225	valid_1's rmse: 90.9646
# [514]	training's rmse: 78.8892	valid_1's rmse: 90.9389
# [515]	training's rmse: 78.8757	valid_1's rmse: 90.9354
# [516]	training's rmse: 78.8483	valid_1's rmse: 90.9151
# [517]	training's rmse: 78.8013	valid_1's rmse: 90.9331
# [518]	training's rmse: 78.7869	valid_1's rmse: 90.9259
# [519]	training's rmse: 78.7629	valid_1's rmse: 90.9053
# [520]	training's rmse: 78.7363	valid_1's rmse: 90.8964
# [521]	training's rmse: 78.7185	valid_1's rmse: 90.8902
# [522]	training's rmse: 78.6954	valid_1's rmse: 90.8825
# [523]	training's rmse: 78.6699	valid_1's rmse: 90.8666
# [524]	training's rmse: 78.6514	valid_1's rmse: 90.8539
# [525]	training's rmse: 78.6181	valid_1's rmse: 90.8454
# [526]	training's rmse: 78.6023	valid_1's rmse: 90.8445
# [527]	training's rmse: 78.589	valid_1's rmse: 90.8433
# [528]	training's rmse: 78.5689	valid_1's rmse: 90.83
# [529]	training's rmse: 78.5601	valid_1's rmse: 90.8238
# [530]	training's rmse: 78.5531	valid_1's rmse: 90.8195
# [531]	training's rmse: 78.5185	valid_1's rmse: 90.7947
# [532]	training's rmse: 78.478	valid_1's rmse: 90.7782
# [533]	training's rmse: 78.4536	valid_1's rmse: 90.7748
# [534]	training's rmse: 78.4296	valid_1's rmse: 90.7564
# [535]	training's rmse: 78.4043	valid_1's rmse: 90.749
# [536]	training's rmse: 78.3814	valid_1's rmse: 90.7306
# [537]	training's rmse: 78.3664	valid_1's rmse: 90.7248
# [538]	training's rmse: 78.3553	valid_1's rmse: 90.7205
# [539]	training's rmse: 78.3335	valid_1's rmse: 90.7144
# [540]	training's rmse: 78.3034	valid_1's rmse: 90.6941
# [541]	training's rmse: 78.3021	valid_1's rmse: 90.6932
# [542]	training's rmse: 78.2656	valid_1's rmse: 90.7046
# [543]	training's rmse: 78.2403	valid_1's rmse: 90.683
# [544]	training's rmse: 78.1956	valid_1's rmse: 90.6731
# [545]	training's rmse: 78.1697	valid_1's rmse: 90.6576
# [546]	training's rmse: 78.1462	valid_1's rmse: 90.6451
# [547]	training's rmse: 78.0944	valid_1's rmse: 90.6268
# [548]	training's rmse: 78.0815	valid_1's rmse: 90.6226
# [549]	training's rmse: 78.0653	valid_1's rmse: 90.6144
# [550]	training's rmse: 78.0412	valid_1's rmse: 90.605
# [551]	training's rmse: 77.9631	valid_1's rmse: 90.5931
# [552]	training's rmse: 77.9395	valid_1's rmse: 90.5815
# [553]	training's rmse: 77.9072	valid_1's rmse: 90.5803
# [554]	training's rmse: 77.8744	valid_1's rmse: 90.5722
# [555]	training's rmse: 77.8573	valid_1's rmse: 90.5643
# [556]	training's rmse: 77.8311	valid_1's rmse: 90.5469
# [557]	training's rmse: 77.7964	valid_1's rmse: 90.5247
# [558]	training's rmse: 77.7821	valid_1's rmse: 90.5179
# [559]	training's rmse: 77.7656	valid_1's rmse: 90.5141
# [560]	training's rmse: 77.7465	valid_1's rmse: 90.4967
# [561]	training's rmse: 77.728	valid_1's rmse: 90.4845
# [562]	training's rmse: 77.7065	valid_1's rmse: 90.4686
# [563]	training's rmse: 77.689	valid_1's rmse: 90.4573
# [564]	training's rmse: 77.6418	valid_1's rmse: 90.4093
# [565]	training's rmse: 77.6255	valid_1's rmse: 90.403
# [566]	training's rmse: 77.6099	valid_1's rmse: 90.3976
# [567]	training's rmse: 77.5887	valid_1's rmse: 90.38
# [568]	training's rmse: 77.5433	valid_1's rmse: 90.3543
# [569]	training's rmse: 77.5249	valid_1's rmse: 90.3355
# [570]	training's rmse: 77.511	valid_1's rmse: 90.3304
# [571]	training's rmse: 77.4929	valid_1's rmse: 90.3139
# [572]	training's rmse: 77.4595	valid_1's rmse: 90.3039
# [573]	training's rmse: 77.4156	valid_1's rmse: 90.2814
# [574]	training's rmse: 77.3852	valid_1's rmse: 90.2746
# [575]	training's rmse: 77.3602	valid_1's rmse: 90.2597
# [576]	training's rmse: 77.3135	valid_1's rmse: 90.2438
# [577]	training's rmse: 77.2888	valid_1's rmse: 90.2304
# [578]	training's rmse: 77.2692	valid_1's rmse: 90.2196
# [579]	training's rmse: 77.2527	valid_1's rmse: 90.2055
# [580]	training's rmse: 77.2331	valid_1's rmse: 90.1964
# [581]	training's rmse: 77.1714	valid_1's rmse: 90.1848
# [582]	training's rmse: 77.1479	valid_1's rmse: 90.1732
# [583]	training's rmse: 77.1279	valid_1's rmse: 90.1546
# [584]	training's rmse: 77.1117	valid_1's rmse: 90.1488
# [585]	training's rmse: 77.0951	valid_1's rmse: 90.134
# [586]	training's rmse: 77.063	valid_1's rmse: 90.1448
# [587]	training's rmse: 77.0407	valid_1's rmse: 90.13
# [588]	training's rmse: 77.004	valid_1's rmse: 90.1326
# [589]	training's rmse: 76.9902	valid_1's rmse: 90.1278
# [590]	training's rmse: 76.9724	valid_1's rmse: 90.1093
# [591]	training's rmse: 76.952	valid_1's rmse: 90.0985
# [592]	training's rmse: 76.9296	valid_1's rmse: 90.103
# [593]	training's rmse: 76.9199	valid_1's rmse: 90.0951
# [594]	training's rmse: 76.9052	valid_1's rmse: 90.0842
# [595]	training's rmse: 76.878	valid_1's rmse: 90.0597
# [596]	training's rmse: 76.8706	valid_1's rmse: 90.0546
# [597]	training's rmse: 76.8578	valid_1's rmse: 90.0448
# [598]	training's rmse: 76.8402	valid_1's rmse: 90.0413
# [599]	training's rmse: 76.8071	valid_1's rmse: 90.0102
# [600]	training's rmse: 76.774	valid_1's rmse: 89.9882
# [601]	training's rmse: 76.7563	valid_1's rmse: 89.9805
# [602]	training's rmse: 76.7335	valid_1's rmse: 89.9691
# [603]	training's rmse: 76.7208	valid_1's rmse: 89.9672
# [604]	training's rmse: 76.7059	valid_1's rmse: 89.9595
# [605]	training's rmse: 76.6977	valid_1's rmse: 89.9529
# [606]	training's rmse: 76.6851	valid_1's rmse: 89.9417
# [656]	training's rmse: 75.5218	valid_1's rmse: 89.2601
# [657]	training's rmse: 75.5091	valid_1's rmse: 89.2523
# [658]	training's rmse: 75.4813	valid_1's rmse: 89.2528
# [659]	training's rmse: 75.4696	valid_1's rmse: 89.2435
# [660]	training's rmse: 75.4198	valid_1's rmse: 89.2076
# [661]	training's rmse: 75.3977	valid_1's rmse: 89.1802
# [662]	training's rmse: 75.3921	valid_1's rmse: 89.177
# [663]	training's rmse: 75.3768	valid_1's rmse: 89.1686
# [664]	training's rmse: 75.3626	valid_1's rmse: 89.1617
# [665]	training's rmse: 75.3434	valid_1's rmse: 89.1566
# [666]	training's rmse: 75.3289	valid_1's rmse: 89.1432
# [667]	training's rmse: 75.3147	valid_1's rmse: 89.1376
# [668]	training's rmse: 75.3001	valid_1's rmse: 89.1265
# [669]	training's rmse: 75.2735	valid_1's rmse: 89.1248
# [670]	training's rmse: 75.2591	valid_1's rmse: 89.1129
# [671]	training's rmse: 75.2257	valid_1's rmse: 89.1004
# [672]	training's rmse: 75.1971	valid_1's rmse: 89.0904
# [673]	training's rmse: 75.1841	valid_1's rmse: 89.084
# [674]	training's rmse: 75.1399	valid_1's rmse: 89.0693
# [675]	training's rmse: 75.1213	valid_1's rmse: 89.0517
# [676]	training's rmse: 75.1153	valid_1's rmse: 89.0493
# [677]	training's rmse: 75.1087	valid_1's rmse: 89.0451
# [678]	training's rmse: 75.1006	valid_1's rmse: 89.0431
# [679]	training's rmse: 75.0642	valid_1's rmse: 89.0281
# [680]	training's rmse: 75.0457	valid_1's rmse: 89.0128
# [681]	training's rmse: 75.0222	valid_1's rmse: 89.0001
# [682]	training's rmse: 75.0066	valid_1's rmse: 88.987
# [683]	training's rmse: 74.9903	valid_1's rmse: 88.9807
# [684]	training's rmse: 74.9665	valid_1's rmse: 88.96
# [685]	training's rmse: 74.9538	valid_1's rmse: 88.9493
# [686]	training's rmse: 74.9059	valid_1's rmse: 88.9278
# [687]	training's rmse: 74.8648	valid_1's rmse: 88.8935
# [688]	training's rmse: 74.8258	valid_1's rmse: 88.87
# [689]	training's rmse: 74.813	valid_1's rmse: 88.8613
# [690]	training's rmse: 74.7969	valid_1's rmse: 88.8572
# [691]	training's rmse: 74.7674	valid_1's rmse: 88.8492
# [692]	training's rmse: 74.7376	valid_1's rmse: 88.834
# [693]	training's rmse: 74.7052	valid_1's rmse: 88.8175
# [694]	training's rmse: 74.693	valid_1's rmse: 88.8151
# [695]	training's rmse: 74.6697	valid_1's rmse: 88.8151
# [696]	training's rmse: 74.6561	valid_1's rmse: 88.8017
# [697]	training's rmse: 74.6333	valid_1's rmse: 88.7903
# [698]	training's rmse: 74.5879	valid_1's rmse: 88.7672
# [699]	training's rmse: 74.5543	valid_1's rmse: 88.762
# [700]	training's rmse: 74.5413	valid_1's rmse: 88.759
# [701]	training's rmse: 74.5235	valid_1's rmse: 88.7442
# [702]	training's rmse: 74.5044	valid_1's rmse: 88.7418
# [703]	training's rmse: 74.4681	valid_1's rmse: 88.7208
# [704]	training's rmse: 74.4562	valid_1's rmse: 88.7172
# [705]	training's rmse: 74.4415	valid_1's rmse: 88.7115
# [706]	training's rmse: 74.4166	valid_1's rmse: 88.7073
# [707]	training's rmse: 74.3747	valid_1's rmse: 88.6969
# [708]	training's rmse: 74.3021	valid_1's rmse: 88.6385
# [709]	training's rmse: 74.2757	valid_1's rmse: 88.6197
# [710]	training's rmse: 74.2409	valid_1's rmse: 88.6011
# [711]	training's rmse: 74.2158	valid_1's rmse: 88.5812
# [712]	training's rmse: 74.1845	valid_1's rmse: 88.566
# [713]	training's rmse: 74.1543	valid_1's rmse: 88.5561
# [714]	training's rmse: 74.1328	valid_1's rmse: 88.5408
# [715]	training's rmse: 74.1122	valid_1's rmse: 88.5351
# [716]	training's rmse: 74.0804	valid_1's rmse: 88.511
# [717]	training's rmse: 74.0611	valid_1's rmse: 88.5112
# [718]	training's rmse: 74.0474	valid_1's rmse: 88.5079
# [719]	training's rmse: 74.032	valid_1's rmse: 88.4942
# [720]	training's rmse: 74.0185	valid_1's rmse: 88.4908
# [721]	training's rmse: 73.9968	valid_1's rmse: 88.4767
# [722]	training's rmse: 73.9614	valid_1's rmse: 88.4652
# [723]	training's rmse: 73.9425	valid_1's rmse: 88.4559
# [724]	training's rmse: 73.9233	valid_1's rmse: 88.4413
# [725]	training's rmse: 73.8954	valid_1's rmse: 88.4268
# [726]	training's rmse: 73.8817	valid_1's rmse: 88.4216
# [727]	training's rmse: 73.8669	valid_1's rmse: 88.4094
# [728]	training's rmse: 73.851	valid_1's rmse: 88.3989
# [729]	training's rmse: 73.843	valid_1's rmse: 88.3941
# [730]	training's rmse: 73.8273	valid_1's rmse: 88.3779
# [731]	training's rmse: 73.7968	valid_1's rmse: 88.3578
# [732]	training's rmse: 73.79	valid_1's rmse: 88.353
# [733]	training's rmse: 73.7648	valid_1's rmse: 88.3396
# [734]	training's rmse: 73.7142	valid_1's rmse: 88.3315
# [735]	training's rmse: 73.7127	valid_1's rmse: 88.3307
# [736]	training's rmse: 73.6713	valid_1's rmse: 88.3019
# [737]	training's rmse: 73.6441	valid_1's rmse: 88.2848
# [738]	training's rmse: 73.6351	valid_1's rmse: 88.2828
# [739]	training's rmse: 73.6282	valid_1's rmse: 88.2836
# [740]	training's rmse: 73.5783	valid_1's rmse: 88.2587
# [741]	training's rmse: 73.5463	valid_1's rmse: 88.2369
# [742]	training's rmse: 73.5327	valid_1's rmse: 88.2289
# [743]	training's rmse: 73.5231	valid_1's rmse: 88.2261
# [744]	training's rmse: 73.52	valid_1's rmse: 88.2242
# [745]	training's rmse: 73.4909	valid_1's rmse: 88.196
# [746]	training's rmse: 73.4776	valid_1's rmse: 88.1886
# [747]	training's rmse: 73.469	valid_1's rmse: 88.1862
# [748]	training's rmse: 73.4524	valid_1's rmse: 88.1775
# [749]	training's rmse: 73.4436	valid_1's rmse: 88.1753
# [750]	training's rmse: 73.4425	valid_1's rmse: 88.1748
# [751]	training's rmse: 73.4131	valid_1's rmse: 88.1641
# [752]	training's rmse: 73.3965	valid_1's rmse: 88.1713
# [753]	training's rmse: 73.3836	valid_1's rmse: 88.1684
# [754]	training's rmse: 73.3725	valid_1's rmse: 88.16
# [755]	training's rmse: 73.3592	valid_1's rmse: 88.1501
# [756]	training's rmse: 73.3448	valid_1's rmse: 88.1413
# [757]	training's rmse: 73.3238	valid_1's rmse: 88.1392
# [758]	training's rmse: 73.2954	valid_1's rmse: 88.1269
# [759]	training's rmse: 73.276	valid_1's rmse: 88.1092
# [760]	training's rmse: 73.2408	valid_1's rmse: 88.105
# [761]	training's rmse: 73.2055	valid_1's rmse: 88.0985
# [762]	training's rmse: 73.1872	valid_1's rmse: 88.0942
# [763]	training's rmse: 73.175	valid_1's rmse: 88.0892
# [764]	training's rmse: 73.1644	valid_1's rmse: 88.0757
# [765]	training's rmse: 73.1507	valid_1's rmse: 88.073
# [766]	training's rmse: 73.1309	valid_1's rmse: 88.0644
# [767]	training's rmse: 73.1134	valid_1's rmse: 88.0508
# [768]	training's rmse: 73.0963	valid_1's rmse: 88.0376
# [769]	training's rmse: 73.0749	valid_1's rmse: 88.0143
# [770]	training's rmse: 73.0654	valid_1's rmse: 88.0094
# [771]	training's rmse: 73.0531	valid_1's rmse: 88.0008
# [772]	training's rmse: 73.0409	valid_1's rmse: 87.9994
# [773]	training's rmse: 73.0319	valid_1's rmse: 87.9913
# [774]	training's rmse: 73.0204	valid_1's rmse: 87.9848
# [775]	training's rmse: 73.0119	valid_1's rmse: 87.9793
# [776]	training's rmse: 73.0001	valid_1's rmse: 87.9763
# [777]	training's rmse: 72.9859	valid_1's rmse: 87.9645
# [778]	training's rmse: 72.9732	valid_1's rmse: 87.9603
# [779]	training's rmse: 72.9535	valid_1's rmse: 87.948
# [780]	training's rmse: 72.9113	valid_1's rmse: 87.9435
# [781]	training's rmse: 72.8936	valid_1's rmse: 87.9352
# [782]	training's rmse: 72.8761	valid_1's rmse: 87.924
# [783]	training's rmse: 72.8613	valid_1's rmse: 87.9239
# [784]	training's rmse: 72.8524	valid_1's rmse: 87.9207
# [785]	training's rmse: 72.8265	valid_1's rmse: 87.9035
# [786]	training's rmse: 72.8245	valid_1's rmse: 87.9021
# [787]	training's rmse: 72.8163	valid_1's rmse: 87.9002
# [788]	training's rmse: 72.8036	valid_1's rmse: 87.8897
# [789]	training's rmse: 72.7975	valid_1's rmse: 87.8866
# [790]	training's rmse: 72.7402	valid_1's rmse: 87.844
# [791]	training's rmse: 72.7067	valid_1's rmse: 87.8238
# [792]	training's rmse: 72.659	valid_1's rmse: 87.7898
# [793]	training's rmse: 72.6251	valid_1's rmse: 87.7617
# [794]	training's rmse: 72.5891	valid_1's rmse: 87.7383
# [795]	training's rmse: 72.5568	valid_1's rmse: 87.7119
# [796]	training's rmse: 72.5502	valid_1's rmse: 87.7085
# [797]	training's rmse: 72.5405	valid_1's rmse: 87.7041
# [798]	training's rmse: 72.526	valid_1's rmse: 87.693
# [799]	training's rmse: 72.5178	valid_1's rmse: 87.6877
# [800]	training's rmse: 72.4954	valid_1's rmse: 87.6745
# [801]	training's rmse: 72.4795	valid_1's rmse: 87.6617
# [802]	training's rmse: 72.4461	valid_1's rmse: 87.6368
# [803]	training's rmse: 72.4339	valid_1's rmse: 87.6279
# [804]	training's rmse: 72.4269	valid_1's rmse: 87.626
# [805]	training's rmse: 72.4171	valid_1's rmse: 87.6184
# [806]	training's rmse: 72.3754	valid_1's rmse: 87.612
# [807]	training's rmse: 72.3641	valid_1's rmse: 87.6074
# [808]	training's rmse: 72.3161	valid_1's rmse: 87.5653
# [809]	training's rmse: 72.2943	valid_1's rmse: 87.5472
# [810]	training's rmse: 72.2783	valid_1's rmse: 87.5357
# [811]	training's rmse: 72.2405	valid_1's rmse: 87.495
# [812]	training's rmse: 72.2304	valid_1's rmse: 87.4927
# [813]	training's rmse: 72.2066	valid_1's rmse: 87.487
# [814]	training's rmse: 72.1981	valid_1's rmse: 87.4827
# [815]	training's rmse: 72.1484	valid_1's rmse: 87.462
# [816]	training's rmse: 72.1392	valid_1's rmse: 87.4566
# [817]	training's rmse: 72.118	valid_1's rmse: 87.4568
# [818]	training's rmse: 72.1079	valid_1's rmse: 87.4617
# [819]	training's rmse: 72.107	valid_1's rmse: 87.4612
# [820]	training's rmse: 72.0822	valid_1's rmse: 87.4448
# [821]	training's rmse: 72.0553	valid_1's rmse: 87.4379
# [822]	training's rmse: 72.0098	valid_1's rmse: 87.4305
# [823]	training's rmse: 71.9838	valid_1's rmse: 87.418
# [824]	training's rmse: 71.9454	valid_1's rmse: 87.404
# [825]	training's rmse: 71.931	valid_1's rmse: 87.3996
# [826]	training's rmse: 71.9196	valid_1's rmse: 87.3913
# [827]	training's rmse: 71.9099	valid_1's rmse: 87.3854
# [828]	training's rmse: 71.8957	valid_1's rmse: 87.373
# [829]	training's rmse: 71.8786	valid_1's rmse: 87.3594
# [830]	training's rmse: 71.8721	valid_1's rmse: 87.3541
# [831]	training's rmse: 71.8588	valid_1's rmse: 87.3477
# [832]	training's rmse: 71.8543	valid_1's rmse: 87.3458
# [833]	training's rmse: 71.8266	valid_1's rmse: 87.3275
# [834]	training's rmse: 71.8116	valid_1's rmse: 87.3152
# [835]	training's rmse: 71.7991	valid_1's rmse: 87.3114
# [836]	training's rmse: 71.7864	valid_1's rmse: 87.2991
# [837]	training's rmse: 71.7732	valid_1's rmse: 87.2955
# [838]	training's rmse: 71.7588	valid_1's rmse: 87.2848
# [839]	training's rmse: 71.7488	valid_1's rmse: 87.2828
# [840]	training's rmse: 71.7337	valid_1's rmse: 87.2726
# [841]	training's rmse: 71.7203	valid_1's rmse: 87.2597
# [842]	training's rmse: 71.701	valid_1's rmse: 87.265
# [843]	training's rmse: 71.6929	valid_1's rmse: 87.2603
# [844]	training's rmse: 71.6843	valid_1's rmse: 87.2586
# [845]	training's rmse: 71.671	valid_1's rmse: 87.2513
# [846]	training's rmse: 71.6603	valid_1's rmse: 87.245
# [847]	training's rmse: 71.6486	valid_1's rmse: 87.2368
# [848]	training's rmse: 71.6313	valid_1's rmse: 87.2337
# [849]	training's rmse: 71.6221	valid_1's rmse: 87.2322
# [850]	training's rmse: 71.6143	valid_1's rmse: 87.2305
# [851]	training's rmse: 71.5938	valid_1's rmse: 87.2186
# [852]	training's rmse: 71.5726	valid_1's rmse: 87.2042
# [853]	training's rmse: 71.5556	valid_1's rmse: 87.1952
# [854]	training's rmse: 71.5182	valid_1's rmse: 87.1817
# [855]	training's rmse: 71.4902	valid_1's rmse: 87.1798
# [856]	training's rmse: 71.47	valid_1's rmse: 87.1776
# [857]	training's rmse: 71.4512	valid_1's rmse: 87.1665
# [858]	training's rmse: 71.4469	valid_1's rmse: 87.165
# [859]	training's rmse: 71.4363	valid_1's rmse: 87.1572
# [860]	training's rmse: 71.4175	valid_1's rmse: 87.1434
# [861]	training's rmse: 71.3882	valid_1's rmse: 87.1239
# [862]	training's rmse: 71.3511	valid_1's rmse: 87.1164
# [863]	training's rmse: 71.339	valid_1's rmse: 87.1099
# [864]	training's rmse: 71.2932	valid_1's rmse: 87.079
# [865]	training's rmse: 71.2451	valid_1's rmse: 87.0414
# [866]	training's rmse: 71.2053	valid_1's rmse: 87.0169
# [867]	training's rmse: 71.1887	valid_1's rmse: 87.0161
# [868]	training's rmse: 71.1589	valid_1's rmse: 87.01
# [869]	training's rmse: 71.1483	valid_1's rmse: 87.0004
# [870]	training's rmse: 71.1351	valid_1's rmse: 86.9892
# [871]	training's rmse: 71.1046	valid_1's rmse: 86.9821
# [872]	training's rmse: 71.0935	valid_1's rmse: 86.9773
# [873]	training's rmse: 71.0784	valid_1's rmse: 86.9641
# [874]	training's rmse: 71.0729	valid_1's rmse: 86.9635
# [875]	training's rmse: 71.0616	valid_1's rmse: 86.9594
# [876]	training's rmse: 71.054	valid_1's rmse: 86.954
# [877]	training's rmse: 71.0406	valid_1's rmse: 86.9483
# [878]	training's rmse: 71.0268	valid_1's rmse: 86.9379
# [879]	training's rmse: 71.0125	valid_1's rmse: 86.9295
# [880]	training's rmse: 71.0069	valid_1's rmse: 86.926
# [881]	training's rmse: 70.9917	valid_1's rmse: 86.9183
# [882]	training's rmse: 70.9871	valid_1's rmse: 86.9156
# [883]	training's rmse: 70.9828	valid_1's rmse: 86.9125
# [884]	training's rmse: 70.9684	valid_1's rmse: 86.9009
# [885]	training's rmse: 70.9571	valid_1's rmse: 86.9004
# [886]	training's rmse: 70.9469	valid_1's rmse: 86.8914
# [887]	training's rmse: 70.9114	valid_1's rmse: 86.8701
# [888]	training's rmse: 70.8945	valid_1's rmse: 86.8611
# [889]	training's rmse: 70.8856	valid_1's rmse: 86.8552
# [890]	training's rmse: 70.845	valid_1's rmse: 86.8341
# [891]	training's rmse: 70.7908	valid_1's rmse: 86.7885
# [892]	training's rmse: 70.7834	valid_1's rmse: 86.7836
# [893]	training's rmse: 70.7753	valid_1's rmse: 86.7798
# [894]	training's rmse: 70.7538	valid_1's rmse: 86.762
# [895]	training's rmse: 70.7496	valid_1's rmse: 86.7594
# [896]	training's rmse: 70.7288	valid_1's rmse: 86.7441
# [897]	training's rmse: 70.721	valid_1's rmse: 86.7422
# [898]	training's rmse: 70.716	valid_1's rmse: 86.7402
# [899]	training's rmse: 70.7017	valid_1's rmse: 86.7311
# [900]	training's rmse: 70.6965	valid_1's rmse: 86.7284
# [901]	training's rmse: 70.681	valid_1's rmse: 86.7166
# [902]	training's rmse: 70.6696	valid_1's rmse: 86.7114
# [903]	training's rmse: 70.6552	valid_1's rmse: 86.7
# [904]	training's rmse: 70.6525	valid_1's rmse: 86.6991
# [905]	training's rmse: 70.65	valid_1's rmse: 86.6977
# [906]	training's rmse: 70.6398	valid_1's rmse: 86.6973
# [907]	training's rmse: 70.635	valid_1's rmse: 86.6932
# [908]	training's rmse: 70.6232	valid_1's rmse: 86.6906
# [909]	training's rmse: 70.601	valid_1's rmse: 86.6797
# [910]	training's rmse: 70.5776	valid_1's rmse: 86.6663
# [911]	training's rmse: 70.5693	valid_1's rmse: 86.6596
# [912]	training's rmse: 70.5409	valid_1's rmse: 86.6431
# [913]	training's rmse: 70.5332	valid_1's rmse: 86.6419
# [914]	training's rmse: 70.506	valid_1's rmse: 86.6207
# [915]	training's rmse: 70.4794	valid_1's rmse: 86.6199
# [916]	training's rmse: 70.4594	valid_1's rmse: 86.6049
# [917]	training's rmse: 70.4397	valid_1's rmse: 86.5919
# [918]	training's rmse: 70.4289	valid_1's rmse: 86.5843
# [919]	training's rmse: 70.3778	valid_1's rmse: 86.5613
# [920]	training's rmse: 70.3574	valid_1's rmse: 86.5526
# [921]	training's rmse: 70.3467	valid_1's rmse: 86.5481
# [922]	training's rmse: 70.3223	valid_1's rmse: 86.5342
# [923]	training's rmse: 70.2853	valid_1's rmse: 86.5247
# [924]	training's rmse: 70.2568	valid_1's rmse: 86.5072
# [925]	training's rmse: 70.2516	valid_1's rmse: 86.5062
# [926]	training's rmse: 70.2476	valid_1's rmse: 86.5063
# [927]	training's rmse: 70.2377	valid_1's rmse: 86.5058
# [928]	training's rmse: 70.2306	valid_1's rmse: 86.5026
# [929]	training's rmse: 70.2168	valid_1's rmse: 86.4983
# [930]	training's rmse: 70.208	valid_1's rmse: 86.4915
# [931]	training's rmse: 70.181	valid_1's rmse: 86.4726
# [932]	training's rmse: 70.1644	valid_1's rmse: 86.4597
# [933]	training's rmse: 70.1495	valid_1's rmse: 86.4425
# [934]	training's rmse: 70.1325	valid_1's rmse: 86.4348
# [935]	training's rmse: 70.102	valid_1's rmse: 86.4198
# [936]	training's rmse: 70.0929	valid_1's rmse: 86.4175
# [937]	training's rmse: 70.0752	valid_1's rmse: 86.4081
# [938]	training's rmse: 70.0513	valid_1's rmse: 86.383
# [939]	training's rmse: 70.0412	valid_1's rmse: 86.3819
# [940]	training's rmse: 70.0316	valid_1's rmse: 86.3742
# [941]	training's rmse: 70.0223	valid_1's rmse: 86.3681
# [942]	training's rmse: 70.0149	valid_1's rmse: 86.3668
# [943]	training's rmse: 70.0046	valid_1's rmse: 86.3661
# [944]	training's rmse: 69.9933	valid_1's rmse: 86.3555
# [945]	training's rmse: 69.9834	valid_1's rmse: 86.3525
# [946]	training's rmse: 69.9689	valid_1's rmse: 86.3519
# [947]	training's rmse: 69.9597	valid_1's rmse: 86.3482
# [948]	training's rmse: 69.9352	valid_1's rmse: 86.339
# [949]	training's rmse: 69.9209	valid_1's rmse: 86.3429
# [950]	training's rmse: 69.9107	valid_1's rmse: 86.3355
# [951]	training's rmse: 69.8733	valid_1's rmse: 86.3028
# [952]	training's rmse: 69.842	valid_1's rmse: 86.2865
# [953]	training's rmse: 69.8132	valid_1's rmse: 86.2797
# [954]	training's rmse: 69.7963	valid_1's rmse: 86.2681
# [955]	training's rmse: 69.7701	valid_1's rmse: 86.2594
# [956]	training's rmse: 69.7521	valid_1's rmse: 86.2648
# [957]	training's rmse: 69.7348	valid_1's rmse: 86.2588
# [958]	training's rmse: 69.7289	valid_1's rmse: 86.2556
# [959]	training's rmse: 69.7177	valid_1's rmse: 86.2494
# [960]	training's rmse: 69.6952	valid_1's rmse: 86.2362
# [961]	training's rmse: 69.6755	valid_1's rmse: 86.2225
# [962]	training's rmse: 69.6675	valid_1's rmse: 86.2166
# [963]	training's rmse: 69.6531	valid_1's rmse: 86.2067
# [964]	training's rmse: 69.6384	valid_1's rmse: 86.1921
# [965]	training's rmse: 69.6217	valid_1's rmse: 86.1794
# [966]	training's rmse: 69.6037	valid_1's rmse: 86.1783
# [967]	training's rmse: 69.5938	valid_1's rmse: 86.1742
# [968]	training's rmse: 69.5784	valid_1's rmse: 86.1648
# [969]	training's rmse: 69.566	valid_1's rmse: 86.155
# [970]	training's rmse: 69.5401	valid_1's rmse: 86.145
# [971]	training's rmse: 69.5271	valid_1's rmse: 86.1356
# [972]	training's rmse: 69.5129	valid_1's rmse: 86.1275
# [973]	training's rmse: 69.5033	valid_1's rmse: 86.1213
# [974]	training's rmse: 69.4956	valid_1's rmse: 86.1206
# [975]	training's rmse: 69.4838	valid_1's rmse: 86.1082
# [976]	training's rmse: 69.4701	valid_1's rmse: 86.0967
# [977]	training's rmse: 69.4556	valid_1's rmse: 86.0853
# [978]	training's rmse: 69.4453	valid_1's rmse: 86.0743
# [979]	training's rmse: 69.4371	valid_1's rmse: 86.0706
# [980]	training's rmse: 69.4239	valid_1's rmse: 86.0634
# [981]	training's rmse: 69.4086	valid_1's rmse: 86.0605
# [982]	training's rmse: 69.3945	valid_1's rmse: 86.0361
# [983]	training's rmse: 69.3558	valid_1's rmse: 86.0073
# [984]	training's rmse: 69.3241	valid_1's rmse: 85.9803
# [985]	training's rmse: 69.3122	valid_1's rmse: 85.9752
# [986]	training's rmse: 69.3091	valid_1's rmse: 85.9728
# [987]	training's rmse: 69.2996	valid_1's rmse: 85.9786
# [988]	training's rmse: 69.2863	valid_1's rmse: 85.975
# [989]	training's rmse: 69.2736	valid_1's rmse: 85.9665
# [990]	training's rmse: 69.262	valid_1's rmse: 85.9666
# [991]	training's rmse: 69.2515	valid_1's rmse: 85.9675
# [992]	training's rmse: 69.2357	valid_1's rmse: 85.9549
# [993]	training's rmse: 69.2228	valid_1's rmse: 85.9475
# [994]	training's rmse: 69.2095	valid_1's rmse: 85.9538
# [995]	training's rmse: 69.1991	valid_1's rmse: 85.9275
# [996]	training's rmse: 69.1831	valid_1's rmse: 85.9251
# [997]	training's rmse: 69.1704	valid_1's rmse: 85.9239
# [998]	training's rmse: 69.1646	valid_1's rmse: 85.9196
# [999]	training's rmse: 69.1493	valid_1's rmse: 85.9167
# [1000]	training's rmse: 69.1406	valid_1's rmse: 85.9106
# Did not meet early stopping. Best iteration is:
# [1000]	training's rmse: 69.1406	valid_1's rmse: 85.9106

# %%
y_pred = model.predict(x_val, num_iteration=model.best_iteration)

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_val, y_pred)

# %%
r2
# Out:
# 0.846235630359349

# %%
df_train_v1
# Out:
#        mds_fam_id  dc_nbr       date  dept_nbr ind  week  year  month  mds_dc  \
# 0       105899148    6006 2016-11-26        46  tr    47  2016     11       0
# 1       105899148    6006 2016-12-03        46  tr    48  2016     12       0
# 2       105899148    6006 2016-12-10        46  tr    49  2016     12       0
# 3       105899148    6006 2016-12-17        46  tr    50  2016     12       0
# 4       105899148    6006 2016-12-24        46  tr    51  2016     12       0
# ...           ...     ...        ...       ...  ..   ...   ...    ...     ...
# 60404    94169512    7045 2019-06-29        46  tr    26  2019      6     441
# 60405    94169512    7045 2019-07-06        46  tr    27  2019      7     441
# 60406    94169512    7045 2019-07-13        46  tr    28  2019      7     441
# 60407    94169512    7045 2019-07-20        46  tr    29  2019      7     441
# 60408    94169512    7045 2019-07-27        46  tr    30  2019      7     441
#
#        dept_dc  ...  dc_nbrcount1  dept_nbrcount1  weekcount1  yearcount1  \
# 0            3  ...          15.0              14          32        46.5
# 1            3  ...          15.0              14          20        46.5
# 2            3  ...          15.0              14          20        46.5
# 3            3  ...          15.0              14          28        46.5
# 4            3  ...          15.0              14          30        46.5
# ...        ...  ...           ...             ...         ...         ...
# 60404      302  ...          15.0              14          32        32.0
# 60405      302  ...          15.0              14          32        32.0
# 60406      302  ...          15.0              14          32        32.0
# 60407      302  ...          15.0              14          32        32.0
# 60408      302  ...          15.0              14          32        32.0
#
#        monthcount1  mds_dccount1  dept_dccount1  dept_mdscount1  \
# 0               28          32.0           18.0              32
# 1               22          32.0           18.0              32
# 2               22          32.0           18.0              32
# 3               22          32.0           18.0              32
# 4               22          32.0           18.0              32
# ...            ...           ...            ...             ...
# 60404           32           4.0           18.0               5
# 60405           32           4.0           18.0               5
# 60406           32           4.0           18.0               5
# 60407           32           4.0           18.0               5
# 60408           32           4.0           18.0               5
#
#        mds_weekcount1  order
# 0                32.0      4
# 1                23.5     14
# 2                24.5     10
# 3                30.0     20
# 4                32.0     32
# ...               ...    ...
# 60404             5.0      4
# 60405             4.0      4
# 60406             5.0      5
# 60407             5.0      5
# 60408             4.0      3
#
# [56517 rows x 23 columns]

# %%
set(df_test_v1.columns)- set(x_val.columns)
# Out:
# {'date', 'ind', 'order'}

# %%
df_test_v1.sort_values(by=['mds_dc','date'])
# Out:
#        mds_fam_id  dc_nbr       date  dept_nbr ind  week  year  month  mds_dc  \
# 140     105899148    6006 2019-08-10        46  te    32  2019      8       0
# 141     105899148    6006 2019-08-24        46  te    34  2019      8       0
# 142     105899148    6006 2019-09-07        46  te    36  2019      9       0
# 143     105899148    6006 2019-09-21        46  te    38  2019      9       0
# 144     105899148    6006 2019-10-05        46  te    40  2019     10       0
# ...           ...     ...        ...       ...  ..   ...   ...    ...     ...
# 60415    94169512    7045 2019-09-14        46  te    37  2019      9     441
# 60416    94169512    7045 2019-09-21        46  te    38  2019      9     441
# 60417    94169512    7045 2019-09-28        46  te    39  2019      9     441
# 60418    94169512    7045 2019-10-05        46  te    40  2019     10     441
# 60419    94169512    7045 2019-10-19        46  te    42  2019     10     441
#
#        dept_dc  ...  dc_nbrcount1  dept_nbrcount1  weekcount1  yearcount1  \
# 140          3  ...          15.0              14          32        32.0
# 141          3  ...          15.0              14          32        32.0
# 142          3  ...          15.0              14          32        32.0
# 143          3  ...          15.0              14          32        32.0
# 144          3  ...          15.0              14          24        32.0
# ...        ...  ...           ...             ...         ...         ...
# 60415      302  ...          15.0              14          32        32.0
# 60416      302  ...          15.0              14          32        32.0
# 60417      302  ...          15.0              14          32        32.0
# 60418      302  ...          15.0              14          24        32.0
# 60419      302  ...          15.0              14          21        32.0
#
#        monthcount1  mds_dccount1  dept_dccount1  dept_mdscount1  \
# 140             32          32.0           18.0              32
# 141             32          32.0           18.0              32
# 142             32          32.0           18.0              32
# 143             32          32.0           18.0              32
# 144             24          32.0           18.0              32
# ...            ...           ...            ...             ...
# 60415           32           4.0           18.0               5
# 60416           32           4.0           18.0               5
# 60417           32           4.0           18.0               5
# 60418           24           4.0           18.0               5
# 60419           24           4.0           18.0               5
#
#        mds_weekcount1  order
# 140              32.0      0
# 141              32.0      0
# 142              32.0      0
# 143              32.0      0
# 144              32.0      0
# ...               ...    ...
# 60415             7.0      0
# 60416             5.0      0
# 60417             7.5      0
# 60418            16.0      0
# 60419             7.5      0
#
# [3903 rows x 23 columns]

# %%
df_test_v2 = df_test_v1.drop(['date', 'ind', 'order'],axis=1)

# %%
y_pred_test = model.predict(df_test_v2, num_iteration=model.best_iteration)

# %%
y_pred_test
# Out:
# array([31.96930875, 31.17756331, 30.7180679 , ...,  7.79978682,
#        17.68105335, 11.16430988])

# %%
y_pred_test = [0.1 if x < 0 else x for x in y_pred_test]

# %%
df_test_v1['order'] = y_pred_test
# Out:
# /Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test_v1.head()
# Out:
#      mds_fam_id  dc_nbr       date  dept_nbr ind  week  year  month  mds_dc  \
# 140   105899148    6006 2019-08-10        46  te    32  2019      8       0
# 141   105899148    6006 2019-08-24        46  te    34  2019      8       0
# 142   105899148    6006 2019-09-07        46  te    36  2019      9       0
# 143   105899148    6006 2019-09-21        46  te    38  2019      9       0
# 144   105899148    6006 2019-10-05        46  te    40  2019     10       0
#
#      dept_dc  ...  dc_nbrcount1  dept_nbrcount1  weekcount1  yearcount1  \
# 140        3  ...          15.0              14          32        32.0
# 141        3  ...          15.0              14          32        32.0
# 142        3  ...          15.0              14          32        32.0
# 143        3  ...          15.0              14          32        32.0
# 144        3  ...          15.0              14          24        32.0
#
#      monthcount1  mds_dccount1  dept_dccount1  dept_mdscount1  mds_weekcount1  \
# 140           32          32.0           18.0              32            32.0
# 141           32          32.0           18.0              32            32.0
# 142           32          32.0           18.0              32            32.0
# 143           32          32.0           18.0              32            32.0
# 144           24          32.0           18.0              32            32.0
#
#          order
# 140  31.969309
# 141  31.177563
# 142  30.718068
# 143  31.416503
# 144  30.349884
#
# [5 rows x 23 columns]

# %%
df_test_v1['date'] = df_test_v1['date'].apply(lambda x : x.strftime("%Y-%m-%d (%H:%M:%S.%f)")[0:10])
# Out:
# /Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dict_map = {}

for i in tqdm(range(0,len(df_test_v1))):
    
    mds = df_test_v1['mds_fam_id'].iloc[i]
    dc =  df_test_v1['dc_nbr'].iloc[i]
    dt =  df_test_v1['date'].iloc[i]
    
    dict_map[(mds,dc,dt)] = df_test_v1['order'].iloc[i]
# Out:
# 100%|██████████| 3903/3903 [00:00<00:00, 16919.84it/s]

# %%
dict_dt = {}

for i in tqdm(range(0,len(x_test))):
    
    dict_dt[x_test['wm_year_wk_nbr'].iloc[i]] = x_test['date'].iloc[i]
# Out:
# 100%|██████████| 3903/3903 [00:00<00:00, 32375.22it/s]

# %%
final_test = pd.read_excel('/Users/s0c02nj/Desktop/test_merch.xlsx')

# %%
order = []

for i in tqdm(range(0,len(final_test))):
    
    mds = final_test['mds_fam_id'].iloc[i]
    dc =  final_test['dc_nbr'].iloc[i]
    dt =  dict_dt[final_test['wm_year_wk_nbr'].iloc[i]]
    
    order.append(dict_map[(mds,dc,dt)])
# Out:
# 100%|██████████| 3903/3903 [00:00<00:00, 21570.81it/s]

# %%
order = [0.1 if x < 0 else x for x in order]

# %%
final_test['predicted_order_qty'] = order
#final_test['predicted_order_qty'] = final_test['predicted_order_qty'] * final_test['vnpk_qty']

# %%
#final_test['predicted_order_qty'] = final_test['predicted_order_qty'] * final_test['vnpk_qty']

# %%
final_test.to_csv('/Users/s0c02nj/Desktop/merch_pred2.csv',index = False)

# %% [markdown]
# #### Time series component

# %%
x_train.columns
# Out:
# Index(['mds_fam_id', 'dc_nbr', 'dept_nbr', 'week', 'year', 'month', 'mds_dc',
#        'dept_dc', 'dept_mds', 'mds_week', 'mds_fam_idcount1', 'dc_nbrcount1',
#        'dept_nbrcount1', 'weekcount1', 'yearcount1', 'monthcount1',
#        'mds_dccount1', 'dept_dccount1', 'dept_mdscount1', 'mds_weekcount1'],
#       dtype='object')

# %%
df_train_v2 = df_train_v1.drop(['date', 'ind', 'order'],axis=1)

# %%
train_pred = model.predict(df_train_v2, num_iteration=model.best_iteration)

# %%
df_train_v1['pred_train'] = train_pred
df_train_v1['date'] = df_train_v1['date'].apply(lambda x : x.strftime("%Y-%m-%d (%H:%M:%S.%f)")[0:10])
# Out:
# /Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dict_map_tr = {}

for i in tqdm(range(0,len(df_train_v1))):
    
    mds = df_train_v1['mds_fam_id'].iloc[i]
    dc =  df_train_v1['dc_nbr'].iloc[i]
    dt =  df_train_v1['date'].iloc[i]
    
    dict_map_tr[(mds,dc,dt)] = df_train_v1['pred_train'].iloc[i]
# Out:
# 100%|██████████| 56517/56517 [00:02<00:00, 21439.93it/s]

# %%
order_tr = []

for i in tqdm(range(0,len(df_train_v1))):
    
    mds = df_train_v1['mds_fam_id'].iloc[i]
    dc =  df_train_v1['dc_nbr'].iloc[i]
    dt =  df_train_v1['date'].iloc[i]
    
    order_tr.append(dict_map_tr[(mds,dc,dt)])
# Out:
# 100%|██████████| 56517/56517 [00:01<00:00, 28320.61it/s]

# %%
order_tr = [0.1 if x < 0 else x for x in order_tr]

# %%
df_train_v1['pred_order'] = order_tr
# Out:
# /Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#x_train['pred_order'] = x_train['pred_order'] * x_train['vnpk_qty']

# %%
df_train_v1['res'] = df_train_v1['order'] - df_train_v1['pred_order']
# Out:
# /Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### Time series approach

# %%
id_unique = list(df_train_v1['mds_dc'].unique())

# %%
dict_tr_te = {}

for i in tqdm(id_unique):
    seq = list(df_train_v1[df_train_v1['mds_dc'] == i]['res'])
    
    if len(seq)!=1:
        model = ExponentialSmoothing(seq).fit()
    else :
        model = ExponentialSmoothing(seq*3).fit()
    
    k = df_test_v1[df_test_v1['mds_dc'] == i].shape[0]
    dict_tr_te[i] = list(model.forecast(k))
# Out:
#   9%|▉         | 40/442 [00:00<00:44,  9.04it/s]/Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
#  69%|██████▉   | 307/442 [00:01<00:00, 164.63it/s]/Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# /Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# 100%|██████████| 442/442 [00:02<00:00, 176.90it/s]

# %%
df_test_v3 = df_test_v1

# %%
df_test_v3 = pd.DataFrame()

for i in tqdm(id_unique):
    
    df_temp = df_test_v1[df_test_v1['mds_dc'] == i]
    df_temp['ts_ord'] = dict_tr_te[i]
    
    df_test_v3 =  pd.concat([df_test_v3,df_temp],axis=0)
# Out:
#   0%|          | 0/442 [00:00<?, ?it/s]/Users/s0c02nj/anaconda2/envs/graph/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 100%|██████████| 442/442 [00:02<00:00, 152.23it/s]

# %%
df_test_v3
# Out:
#         mds_fam_id  dc_nbr        date  dept_nbr ind  week    year  month  \
# 140    105899148.0  6006.0  2019-08-10      46.0  te  32.0  2019.0    8.0
# 141    105899148.0  6006.0  2019-08-24      46.0  te  34.0  2019.0    8.0
# 142    105899148.0  6006.0  2019-09-07      46.0  te  36.0  2019.0    9.0
# 143    105899148.0  6006.0  2019-09-21      46.0  te  38.0  2019.0    9.0
# 144    105899148.0  6006.0  2019-10-05      46.0  te  40.0  2019.0   10.0
# ...            ...     ...         ...       ...  ..   ...     ...    ...
# 60415   94169512.0  7045.0  2019-09-14      46.0  te  37.0  2019.0    9.0
# 60416   94169512.0  7045.0  2019-09-21      46.0  te  38.0  2019.0    9.0
# 60417   94169512.0  7045.0  2019-09-28      46.0  te  39.0  2019.0    9.0
# 60418   94169512.0  7045.0  2019-10-05      46.0  te  40.0  2019.0   10.0
# 60419   94169512.0  7045.0  2019-10-19      46.0  te  42.0  2019.0   10.0
#
#        mds_dc  dept_dc  ...  weekcount1  yearcount1  monthcount1  \
# 140       0.0      3.0  ...        32.0        32.0         32.0
# 141       0.0      3.0  ...        32.0        32.0         32.0
# 142       0.0      3.0  ...        32.0        32.0         32.0
# 143       0.0      3.0  ...        32.0        32.0         32.0
# 144       0.0      3.0  ...        24.0        32.0         24.0
# ...       ...      ...  ...         ...         ...          ...
# 60415   441.0    302.0  ...        32.0        32.0         32.0
# 60416   441.0    302.0  ...        32.0        32.0         32.0
# 60417   441.0    302.0  ...        32.0        32.0         32.0
# 60418   441.0    302.0  ...        24.0        32.0         24.0
# 60419   441.0    302.0  ...        21.0        32.0         24.0
#
#        mds_dccount1  dept_dccount1  dept_mdscount1  mds_weekcount1      order  \
# 140            32.0           18.0            32.0            32.0  31.969309
# 141            32.0           18.0            32.0            32.0  31.177563
# 142            32.0           18.0            32.0            32.0  30.718068
# 143            32.0           18.0            32.0            32.0  31.416503
# 144            32.0           18.0            32.0            32.0  30.349884
# ...             ...            ...             ...             ...        ...
# 60415           4.0           18.0             5.0             7.0   7.991347
# 60416           4.0           18.0             5.0             5.0   5.312230
# 60417           4.0           18.0             5.0             7.5   7.799787
# 60418           4.0           18.0             5.0            16.0  17.681053
# 60419           4.0           18.0             5.0             7.5  11.164310
#
#          ts_ord  final_ord
# 140   -0.588532  31.380776
# 141   -0.588532  30.589031
# 142   -0.588532  30.129536
# 143   -0.588532  30.827971
# 144   -0.588532  29.761352
# ...         ...        ...
# 60415 -0.652153   7.339194
# 60416 -0.652153   4.660076
# 60417 -0.652153   7.147633
# 60418 -0.652153  17.028900
# 60419 -0.652153  10.512156
#
# [3997 rows x 25 columns]

# %%
df_test_v3['final_ord'] = df_test_v3['order'] + df_test_v3['ts_ord']

# %%
df_test_v3['final_ord'] = df_test_v3['final_ord'].apply(lambda x: 0.5 if x<0 else x)

# %%
dict_map = {}

for i in tqdm(range(0,len(df_test_v3))):
    
    mds = df_test_v3['mds_fam_id'].iloc[i]
    dc =  df_test_v3['dc_nbr'].iloc[i]
    dt =  df_test_v3['date'].iloc[i]
    
    dict_map[(mds,dc,dt)] = df_test_v3['final_ord'].iloc[i]
# Out:
# 100%|██████████| 3997/3997 [00:00<00:00, 16974.76it/s]

# %%
dict_dt = {}

for i in tqdm(range(0,len(x_test))):
    
    dict_dt[x_test['wm_year_wk_nbr'].iloc[i]] = x_test['date'].iloc[i]
# Out:
# 100%|██████████| 3903/3903 [00:00<00:00, 29142.46it/s]

# %%
order = []

for i in tqdm(range(0,len(final_test))):
    
    mds = final_test['mds_fam_id'].iloc[i]
    dc =  final_test['dc_nbr'].iloc[i]
    dt =  dict_dt[final_test['wm_year_wk_nbr'].iloc[i]]
    
    order.append(dict_map[(mds,dc,dt)])
# Out:
# 100%|██████████| 3903/3903 [00:00<00:00, 19995.20it/s]

# %%
final_test['predicted_order_qty'] = order
final_test['predicted_order_qty'] = final_test['predicted_order_qty'] * final_test['vnpk_qty']

# %%
final_test.to_csv('/Users/s0c02nj/Desktop/merch_pred_win.csv',index = False)
