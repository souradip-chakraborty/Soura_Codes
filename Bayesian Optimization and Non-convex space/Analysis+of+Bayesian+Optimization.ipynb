# %%
import numpy as np
import pandas as pd
import csv
import sklearn.ensemble
import sklearn.neighbors
import sklearn.datasets
import sklearn.cross_validation
import random
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn import linear_model
import sklearn.cross_validation
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
import time
import random
from skopt import gp_minimize
# Out:
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
mydata=pd.read_csv('/Users/s0c01xa/Documents/Tree_Meta/Data_tree.csv')
xdata=mydata.drop(['y'],axis=1)
ydata=mydata['y']

# %%
#RANDOM STATE 1
import time
t1=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r=gp_minimize(objective,space,n_calls=100,random_state=1,acq_func='EI',n_random_starts=20)

t2=time.time()
#Parameter Values(params)
print r.x

#Minimal Objective Function
print r.fun

print (t2-t1)
# Out:
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/skopt/optimizer/optimizer.py:384: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# [2, 85, 50, 'gini']
# 1.27604914261
# 67.1775138378

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r)
plt.show()

# %%
#RANDOM STATE 2
import time
t3=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r1=gp_minimize(objective,space,n_calls=200,random_state=2,acq_func='EI',n_random_starts=20)

t4=time.time()
#Parameter Values(params)
print r1.x

#Minimal Objective Function
print r1.fun

print (t4-t3)
# Out:
# [3, 35, 24, 'gini']
# 1.26389197388
# 233.266051054

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r1)
plt.show()

# %%
#RANDOM STATE 5
import time
t5=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r2=gp_minimize(objective,space,n_calls=200,random_state=5,acq_func='EI',n_random_starts=20)

t6=time.time()
#Parameter Values(params)
print r2.x

#Minimal Objective Function
print r2.fun

print (t6-t5)
# Out:
# [3, 68, 50, 'gini']
# 1.26560651956
# 215.371444941

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r2)
plt.show()

# %%
#RANDOM STATE 7
import time
t8=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r3=gp_minimize(objective,space,n_calls=200,random_state=7,acq_func='EI',n_random_starts=20)

t9=time.time()
#Parameter Values(params)
print r3.x

#Minimal Objective Function
print r3.fun

print (t9-t8)
# Out:
# [3, 10, 49, 'gini']
# 1.26560637081
# 252.529828072

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r3)
plt.show()

# %%
#RANDOM STATE 20
import time
t11=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r4=gp_minimize(objective,space,n_calls=200,random_state=20,acq_func='EI',n_random_starts=20)

t12=time.time()
#Parameter Values(params)
print r4.x

#Minimal Objective Function
print r4.fun

print (t12-t11)
# Out:
# [3, 100, 50, 'gini']
# 1.26560651956
# 239.421914101

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r4)
plt.show()

# %%
#RANDOM STATE 50
import time
t15=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r5=gp_minimize(objective,space,n_calls=400,random_state=50,acq_func='EI',n_random_starts=20)

t16=time.time()
#Parameter Values(params)
print r5.x

#Minimal Objective Function
print r5.fun

print (t16-t15)
# Out:
# [3, 2, 24, 'gini']
# 1.26389197388
# 1123.57165003

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r5)
plt.show()

# %%
#RANDOM STATE 50
import time
t19=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r7=gp_minimize(objective,space,n_calls=100,random_state=90,acq_func='EI',n_random_starts=20)

t20=time.time()
#Parameter Values(params)
print r7.x

#Minimal Objective Function
print r7.fun

print (t20-t19)
# Out:
# [3, 29, 26, 'gini']
# 1.26379803102
# 70.6942820549

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r7)
plt.show()

# %%
#RANDOM STATE 50
import time
t21=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r8=gp_minimize(objective,space,n_calls=100,random_state=22,acq_func='EI',n_random_starts=20)

t22=time.time()
#Parameter Values(params)
print r8.x

#Minimal Objective Function
print r8.fun

print (t22-t21)
# Out:
# [3, 41, 49, 'gini']
# 1.26560637081
# 78.0738759041

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r8)
plt.show()

# %%
#RANDOM STATE 7 with PI as the criterion
import time
t8=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r3=gp_minimize(objective,space,n_calls=100,random_state=7,acq_func='PI',n_random_starts=20)

t9=time.time()
#Parameter Values(params)
print r3.x

#Minimal Objective Function
print r3.fun

print (t9-t8)
# Out:
# [3, 19, 50, 'gini']
# 1.26560651956
# 82.182587862

# %%
#RANDOM STATE 7 with hedge as the criterion
import time
t8=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r3=gp_minimize(objective,space,n_calls=100,random_state=7,n_random_starts=20)

t9=time.time()
#Parameter Values(params)
print r3.x

#Minimal Objective Function
print r3.fun

print (t9-t8)
# Out:
# [3, 47, 29, 'gini']
# 1.26529332119
# 103.580841064

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r3)
plt.show()

# %%
#Saves the entire searchspace where it iterates and outputs the corresponding hyperparameters.
hyp_para3=r3.x_iters

#Saves the entire 
logloss3=r3.func_vals

# %%
r3.fun
# Out:
# 1.2652933211912645

# %%
#AFTER GIVING INITIAL SEED

# %%
#optimization_result=np.column_stack((hyp_para3,logloss3))

# %%
#np.savetxt('/Users/s0c01xa/Documents/opt.csv',optimization_result,delimiter=',')

# %%
optimization_result=pd.DataFrame(optimization_result)
#optimization_result

# %%
optimization_result
# Out:
#      0    1   2        3              4
# 0    8   33  49     gini  1.67971776726
# 1   10   28   5     gini  2.65412638837
# 2    1   54  44     gini  1.32844980111
# 3   12   68  34  entropy  1.85076611619
# 4   11   93  14  entropy  1.87646407728
# 5    8   85  10  entropy  1.97544584748
# 6   28   46  20     gini  2.26075465068
# 7    7   12  25  entropy  1.97141266958
# 8   29   36  15     gini  2.35812411341
# 9   29   20   8     gini  2.79721095245
# 10  17   32  15  entropy  2.24233855956
# 11  14   43  49  entropy  1.79710189688
# 12  11   31  26  entropy  1.97085021777
# 13  20   27  21  entropy  2.06602571747
# 14  14   79  35  entropy  1.82547304909
# 15  15   95   9  entropy  1.94634241114
# 16  17   87   8     gini  2.08264393892
# 17  20   67  42  entropy  1.85917171644
# 18   2   11  40     gini  1.28306906046
# 19  21   51  20  entropy  2.00044987787
# 20   1    2  42  entropy  1.32844980111
# 21   1  100  42     gini  1.32844980111
# 22   1  100  47  entropy  1.32844980111
# 23   1    2  42     gini  1.32844980111
# 24   1   15  40     gini  1.32844980111
# 25   1   45  41  entropy  1.32844980111
# 26   1    2  38  entropy  1.32844980111
# 27   1  100  44     gini  1.32844980111
# 28   1  100  26  entropy  1.32844980111
# 29   1  100   1  entropy  1.32844980111
# ..  ..  ...  ..      ...            ...
# 70  12  100  50     gini  1.68029045947
# 71  25   93  50     gini  1.68029045947
# 72   4  100   1     gini  1.31231368576
# 73   4  100  27     gini  1.33659912973
# 74  25    8   1  entropy  4.19544438013
# 75  28  100  50     gini  1.68029045947
# 76  22  100  50  entropy   1.7383950868
# 77  30  100  28  entropy  1.75822125111
# 78   1  100  30  entropy  1.32844980111
# 79   3   60  50     gini  1.26560651956
# 80   3  100  31     gini  1.27153340738
# 81   2   41   1     gini  1.28051344532
# 82   2   37   1     gini  1.28051344532
# 83   3    2  50     gini  1.26560651956
# 84   2    2  30     gini  1.28051344532
# 85   2   37   1     gini  1.28051344532
# 86   2    2  30     gini  1.28051344532
# 87   2  100  23  entropy  1.28139587439
# 88   2  100  14  entropy  1.28139587439
# 89   3  100  20  entropy  1.46381206275
# 90   2  100  18  entropy  1.28139587439
# 91   2  100  18  entropy  1.28139587439
# 92   2    2   1  entropy  1.28139587439
# 93  21   80   1     gini  2.14434343702
# 94   2    2   6  entropy  1.28139587439
# 95  18    2  50     gini  1.68029045947
# 96   2    2   6  entropy  1.28139587439
# 97   2    2  11  entropy  1.28139587439
# 98   2  100  34  entropy  1.27969859298
# 99   2   97   8  entropy  1.28139587439
#
# [100 rows x 5 columns]

# %%
#DEFINING AN INITIAL SEED AND GIVING N_CALLS AS 10

import time
t8=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r3=gp_minimize(objective,space,n_calls=100,random_state=7,n_random_starts=20,x0=[3, 47, 29, 'gini'])

t9=time.time()
#Parameter Values(params)
print r3.x

#Minimal Objective Function
print r3.fun

print (t9-t8)
# Out:
# [3, 2, 26, 'gini']
# 1.26379803102
# 89.8665089607

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r3)
plt.show()

# %%
#DEFINING AN INITIAL startpoint AND GIVING N_CALLS AS 40

import time
t8=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r3=gp_minimize(objective,space,n_calls=40,random_state=7,n_random_starts=20,x0=[3, 47, 29, 'gini'])

t9=time.time()
#Parameter Values(params)
print r3.x

#Minimal Objective Function
print r3.fun

print (t9-t8)
# Out:
# [3, 47, 29, 'gini']
# 1.26529332119
# 19.6960999966

# %%
#DEFINING AN INITIAL startpoint AND GIVING N_CALLS AS 40

import time
t8=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='roc_auc')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r3=gp_minimize(objective,space,n_calls=21,random_state=7,n_random_starts=20)

t9=time.time()
#Parameter Values(params)
print r3.x

#Minimal Objective Function
print r3.fun

print (t9-t8)
# Out:
# [8, 33, 49, 'gini']
# 0.0451604161665
# 3.16223502159

# %%
from skopt.plots import plot_convergence
import matplotlib.pyplot as plt
plot_convergence(r3)
plt.show()

# %%
model=DecisionTreeClassifier(random_state=0,max_depth=3,min_samples_split=47,min_samples_leaf=29,criterion='gini')
    #model.fit(xdata,ydata)
score=1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='roc_auc'))

# %%
score
# Out:
# 0.051549947979191657

# %%
import time
t8=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='roc_auc')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r3=gp_minimize(objective,space,n_calls=21,random_state=7,n_random_starts=20)

t9=time.time()
#Parameter Values(params)
print r3.x

#Minimal Objective Function
print r3.fun

print (t9-t8)

# %%
#DEFINING A FUNCTION INVOLVING BAYESIAN OPTIMIZATION WHILE GIVEN A DATABASE BASED 

import time
t8=time.time()
def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))


space=[(1,30),(2,100),(1,50),('gini','entropy')]
r3=gp_minimize(objective,space,n_calls=100,random_state=7,n_random_starts=20)

t9=time.time()
#Parameter Values(params)
print r3.x

#Minimal Objective Function
print r3.fun

print (t9-t8)

# %%
import time
t10=time.time()

def objective(params):
    max_depth=params[0]
    min_samples_split=params[1]
    min_samples_leaf=params[2]
    criterion=params[3]
    model=DecisionTreeClassifier(random_state=0,max_depth=max_depth,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,criterion=criterion)
    #model.fit(xdata,ydata)
    return (1-np.mean(cross_val_score(model,xdata,ydata,cv=10,scoring='neg_log_loss')))

random_state=[1,3,5,7,9,11,13,15,17,20,25,30,40,45,60,80,90,100,110,120,150,250]
space=[(1,30),(2,100),(1,50),('gini','entropy')]


#Parameter Values(params)
#print r3.x

#Minimal Objective Function
#print r3.fun

Opt_hyp=np.z[]

for r in random_state:
    min_val=gp_minimize(objective,space,n_calls=100,random_state=r,n_random_starts=20)
    min_val.x
    min_val.fun
    Opt_hyp

    
t11=time.time(min_val)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-64a4d6d2a752> in <module>()
#      24
#      25 for r in random_state:
# ---> 26     min_val=gp_minimize(objective,space,n_calls=100,random_state=r,n_random_starts=20)
#      27     Opt_val.append(min_val)
#      28
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/skopt/optimizer/gp.pyc in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs)
#     226         n_restarts_optimizer=n_restarts_optimizer,
#     227         x0=x0, y0=y0, random_state=rng, verbose=verbose,
# --> 228         callback=callback, n_jobs=n_jobs)
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/skopt/optimizer/base.pyc in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs)
#     252
#     253         next_y = func(next_x)
# --> 254         result = optimizer.tell(next_x, next_y)
#     255         result.specs = specs
#     256
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/skopt/optimizer/optimizer.pyc in tell(self, x, y, fit)
#     426                 y[1] = log(y[1])
#     427
# --> 428         return self._tell(x, y, fit=fit)
#     429
#     430     def _tell(self, x, y, fit=True):
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/skopt/optimizer/optimizer.pyc in _tell(self, x, y, fit)
#     469             with warnings.catch_warnings():
#     470                 warnings.simplefilter("ignore")
# --> 471                 est.fit(self.space.transform(self.Xi), self.yi)
#     472
#     473             if hasattr(self, "next_xs_") and self.acq_func == "gp_hedge":
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/skopt/learning/gaussian_process/gpr.pyc in fit(self, X, y)
#     193                 noise_level=self.noise, noise_level_bounds="fixed"
#     194             )
# --> 195         super(GaussianProcessRegressor, self).fit(X, y)
#     196
#     197         self.noise_ = None
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/sklearn/gaussian_process/gpr.pyc in fit(self, X, y)
#     230                     optima.append(
#     231                         self._constrained_optimization(obj_func, theta_initial,
# --> 232                                                        bounds))
#     233             # Select result from run with minimal (negative) log-marginal
#     234             # likelihood
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/sklearn/gaussian_process/gpr.pyc in _constrained_optimization(self, obj_func, initial_theta, bounds)
#     452         if self.optimizer == "fmin_l_bfgs_b":
#     453             theta_opt, func_min, convergence_dict = \
# --> 454                 fmin_l_bfgs_b(obj_func, initial_theta, bounds=bounds)
#     455             if convergence_dict["warnflag"] != 0:
#     456                 warnings.warn("fmin_l_bfgs_b terminated abnormally with the "
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     191
#     192     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 193                            **opts)
#     194     d = {'grad': res['jac'],
#     195          'task': res['message'],
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     326             # until the completion of the current minimization iteration.
#     327             # Overwrite f and g:
# --> 328             f, g = func_and_grad(x)
#     329         elif task_str.startswith(b'NEW_X'):
#     330             # new iteration
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in func_and_grad(x)
#     276     else:
#     277         def func_and_grad(x):
# --> 278             f = fun(x, *args)
#     279             g = jac(x, *args)
#     280             return f, g
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in __call__(self, x, *args)
#      61     def __call__(self, x, *args):
#      62         self.x = numpy.asarray(x).copy()
# ---> 63         fg = self.fun(x, *args)
#      64         self.jac = fg[1]
#      65         return fg[0]
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/sklearn/gaussian_process/gpr.pyc in obj_func(theta, eval_gradient)
#     207                 if eval_gradient:
#     208                     lml, grad = self.log_marginal_likelihood(
# --> 209                         theta, eval_gradient=True)
#     210                     return -lml, -grad
#     211                 else:
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/sklearn/gaussian_process/gpr.pyc in log_marginal_likelihood(self, theta, eval_gradient)
#     410
#     411         if eval_gradient:
# --> 412             K, K_gradient = kernel(self.X_train_, eval_gradient=True)
#     413         else:
#     414             K = kernel(self.X_train_)
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/sklearn/gaussian_process/kernels.pyc in __call__(self, X, Y, eval_gradient)
#     677         """
#     678         if eval_gradient:
# --> 679             K1, K1_gradient = self.k1(X, Y, eval_gradient=True)
#     680             K2, K2_gradient = self.k2(X, Y, eval_gradient=True)
#     681             return K1 + K2, np.dstack((K1_gradient, K2_gradient))
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/sklearn/gaussian_process/kernels.pyc in __call__(self, X, Y, eval_gradient)
#     752         if eval_gradient:
#     753             K1, K1_gradient = self.k1(X, Y, eval_gradient=True)
# --> 754             K2, K2_gradient = self.k2(X, Y, eval_gradient=True)
#     755             return K1 * K2, np.dstack((K1_gradient * K2[:, :, np.newaxis],
#     756                                        K2_gradient * K1[:, :, np.newaxis]))
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/sklearn/gaussian_process/kernels.pyc in __call__(self, X, Y, eval_gradient)
#    1366                     3 * D * np.exp(-np.sqrt(3 * D.sum(-1)))[..., np.newaxis]
#    1367             elif self.nu == 2.5:
# -> 1368                 tmp = np.sqrt(5 * D.sum(-1))[..., np.newaxis]
#    1369                 K_gradient = 5.0 / 3.0 * D * (tmp + 1) * np.exp(-tmp)
#    1370             else:
#
# /Users/s0c01xa/Desktop/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
Opt_val
# Out:
# [          fun: 1.2760491426085872
#     func_vals: array([ 2.04796513,  1.99364943,  1.9732362 ,  1.91335996,  1.79573139,
#         2.14949996,  1.68404453,  1.46578019,  2.37818839,  2.72549824,
#         2.26615116,  1.51949234,  1.96922618,  1.78699209,  2.07661717,
#         1.75356578,  2.60256166,  1.28051345,  1.91335996,  1.94615369,
#         1.3284498 ,  1.3284498 ,  1.28051345,  1.28051345,  1.3284498 ,
#         1.28139587,  1.27604914,  1.28307355,  1.27841744,  1.3284498 ,
#         1.73839509,  1.28051345,  1.28051345,  1.3284498 ,  1.27604914,
#         1.68029046,  1.28139587,  1.28051345,  1.52280553,  1.28139587,
#         1.28051345,  1.27841744,  1.27604914,  1.28051345,  1.28051345,
#         1.28051345,  1.28051345,  1.28051345,  1.28051345,  1.27841744,
#         1.28051345,  1.27841744,  1.28051345,  1.28051345,  1.28051345,
#         1.28051345,  1.28051345,  1.28051345,  1.28051345,  1.28051345,
#         1.28051345,  1.27604914,  1.27604914,  1.28051345,  1.28051345,
#         1.28051345,  1.73839509,  1.27604914,  1.27604914,  1.27604914,
#         1.28051345,  1.73839509,  1.27604914,  1.27604914,  1.27604914,
#         1.28051345,  1.27604914,  1.27604914,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.27604914,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.27604914,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.27604914,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.27604914,  1.27604914,  1.27604914])
#        models: [GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845)]
#  random_state: <mtrand.RandomState object at 0x1121ab050>
#         space: Space([Integer(low=1, high=30),
#        Integer(low=2, high=100),
#        Integer(low=1, high=50),
#        Categorical(categories=('gini', 'entropy'), prior=None)])
#         specs: {'function': 'base_minimize', 'args': {'base_estimator': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=1791095845), 'xi': 0.01, 'verbose': False, 'n_points': 10000, 'acq_func': 'gp_hedge', 'n_jobs': 1, 'func': <function objective at 0x1123c8c80>, 'n_restarts_optimizer': 5, 'y0': None, 'x0': None, 'kappa': 1.96, 'dimensions': Space([Integer(low=1, high=30),
#        Integer(low=2, high=100),
#        Integer(low=1, high=50),
#        Categorical(categories=('gini', 'entropy'), prior=None)]), 'n_calls': 100, 'acq_optimizer': 'auto', 'callback': None, 'random_state': <mtrand.RandomState object at 0x1121ab050>, 'n_random_starts': 20}}
#             x: [2, 2, 49, 'gini']
#       x_iters: [[30, 93, 7, 'entropy'], [8, 41, 20, 'entropy'], [28, 85, 16, 'entropy'], [14, 24, 27, 'entropy'], [14, 44, 47, 'entropy'], [22, 81, 6, 'entropy'], [26, 83, 42, 'gini'], [3, 68, 30, 'entropy'], [13, 21, 15, 'gini'], [24, 42, 3, 'entropy'], [20, 31, 23, 'gini'], [3, 48, 6, 'entropy'], [4, 53, 5, 'entropy'], [27, 31, 30, 'entropy'], [19, 96, 14, 'gini'], [16, 95, 25, 'entropy'], [23, 6, 8, 'entropy'], [2, 89, 27, 'gini'], [27, 39, 27, 'entropy'], [11, 58, 32, 'gini'], [1, 100, 32, 'entropy'], [1, 100, 50, 'entropy'], [2, 87, 29, 'gini'], [2, 86, 27, 'gini'], [1, 46, 2, 'entropy'], [2, 76, 15, 'entropy'], [2, 2, 49, 'gini'], [2, 14, 41, 'gini'], [2, 2, 44, 'entropy'], [1, 2, 50, 'gini'], [27, 2, 50, 'entropy'], [2, 19, 13, 'gini'], [2, 2, 13, 'gini'], [1, 2, 16, 'gini'], [2, 45, 50, 'gini'], [30, 100, 50, 'gini'], [2, 100, 9, 'entropy'], [2, 100, 11, 'gini'], [3, 9, 50, 'entropy'], [2, 18, 10, 'entropy'], [2, 90, 10, 'gini'], [2, 100, 37, 'entropy'], [2, 24, 50, 'gini'], [2, 79, 10, 'gini'], [2, 100, 10, 'gini'], [2, 95, 10, 'gini'], [2, 94, 10, 'gini'], [2, 100, 10, 'gini'], [2, 49, 10, 'gini'], [2, 74, 49, 'entropy'], [2, 100, 10, 'gini'], [2, 55, 50, 'entropy'], [2, 70, 10, 'gini'], [2, 99, 10, 'gini'], [2, 64, 10, 'gini'], [2, 74, 10, 'gini'], [2, 100, 10, 'gini'], [2, 100, 10, 'gini'], [2, 54, 10, 'gini'], [2, 85, 10, 'gini'], [2, 100, 10, 'gini'], [2, 90, 49, 'gini'], [2, 56, 49, 'gini'], [2, 96, 10, 'gini'], [2, 100, 11, 'gini'], [2, 2, 1, 'gini'], [9, 90, 50, 'entropy'], [2, 11, 49, 'gini'], [2, 21, 49, 'gini'], [2, 77, 49, 'gini'], [2, 100, 21, 'gini'], [17, 47, 50, 'entropy'], [2, 12, 49, 'gini'], [2, 13, 49, 'gini'], [2, 13, 49, 'gini'], [2, 2, 4, 'gini'], [2, 5, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 4, 49, 'gini'], [2, 11, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 5, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 45, 49, 'gini'], [2, 5, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini'], [2, 11, 49, 'gini'], [2, 2, 49, 'gini'], [2, 2, 49, 'gini']],
#            fun: 1.2651280170343235
#     func_vals: array([ 1.49155225,  3.8681011 ,  1.28043102,  1.97141267,  1.78774701,
#         2.13535152,  1.93911559,  2.76537694,  2.23299264,  2.10809575,
#         1.85669026,  1.79654372,  1.75239555,  2.01228596,  1.65204388,
#         1.91335996,  2.21031311,  2.19930088,  1.9463975 ,  1.73839509,
#         1.3284498 ,  1.27296372,  1.27517201,  1.68029046,  1.28140457,
#         1.3284498 ,  1.28051345,  1.3284498 ,  1.3284498 ,  1.26842337,
#         1.3284498 ,  1.27296372,  1.27148977,  1.26811465,  2.08487967,
#         1.3284498 ,  1.26536428,  1.3284498 ,  1.26560652,  1.27604914,
#         2.17649617,  1.7949375 ,  1.26512802,  1.28051345,  1.68029046,
#         1.27056139,  1.26560652,  1.73839509,  1.26560652,  1.29514825,
#         1.2691087 ,  1.26560652,  1.3284498 ,  1.41367116,  1.31231369,
#         1.2672343 ,  1.29262735,  1.68029046,  1.28269608,  1.27442197,
#         1.28051345,  1.27604914,  1.27604914,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.27604914,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.27604914,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.27604914,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.27604914,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.68029046,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.73839509,  1.27604914,  1.27604914,
#         1.27604914,  1.27604914,  1.27604914,  1.27604914,  1.27604914])
#        models: [GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=218175338), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
# ...
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992)]
#  random_state: <mtrand.RandomState object at 0x1a1cce4460>
#         space: Space([Integer(low=1, high=30),
#        Integer(low=2, high=100),
#        Integer(low=1, high=50),
#        Categorical(categories=('gini', 'entropy'), prior=None)])
#         specs: {'function': 'base_minimize', 'args': {'base_estimator': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5),
#              n_restarts_optimizer=2, noise='gaussian', normalize_y=True,
#              optimizer='fmin_l_bfgs_b', random_state=498468992), 'xi': 0.01, 'verbose': False, 'n_points': 10000, 'acq_func': 'gp_hedge', 'n_jobs': 1, 'func': <function objective at 0x1123c8c80>, 'n_restarts_optimizer': 5, 'y0': None, 'x0': None, 'kappa': 1.96, 'dimensions': Space([Integer(low=1, high=30),
#        Integer(low=2, high=100),
#        Integer(low=1, high=50),
#        Categorical(categories=('gini', 'entropy'), prior=None)]), 'n_calls': 100, 'acq_optimizer': 'auto', 'callback': None, 'random_state': <mtrand.RandomState object at 0x1a1cce4460>, 'n_random_starts': 20}}
#             x: [3, 55, 50, 'gini']
#       x_iters: [[25, 34, 48, 'entropy'], [6, 66, 44, 'gini'], [19, 8, 26, 'gini'], [29, 63, 9, 'gini'], [2, 34, 20, 'entropy'], [3, 82, 17, 'gini'], [29, 92, 29, 'entropy'], [9, 21, 38, 'entropy'], [24, 84, 11, 'gini'], [11, 74, 49, 'gini'], [22, 44, 31, 'entropy'], [27, 19, 15, 'gini'], [15, 84, 27, 'entropy'], [13, 39, 10, 'entropy'], [8, 99, 23, 'gini'], [7, 96, 46, 'entropy'], [9, 80, 14, 'gini'], [7, 4, 10, 'gini'], [6, 15, 30, 'entropy'], [9, 34, 35, 'entropy'], [3, 73, 19, 'gini'], [3, 82, 18, 'gini'], [3, 77, 18, 'gini'], [2, 68, 1, 'gini'], [2, 77, 15, 'gini'], [4, 100, 48, 'entropy'], [3, 75, 15, 'gini'], [3, 73, 4, 'gini'], [3, 72, 8, 'gini'], [3, 78, 8, 'gini'], [1, 2, 6, 'entropy'], [2, 4, 41, 'entropy'], [2, 19, 30, 'gini'], [1, 100, 50, 'gini'], [4, 100, 33, 'gini'], [14, 100, 47, 'gini'], [3, 55, 50, 'gini'], [3, 28, 50, 'gini'], [1, 100, 50, 'entropy'], [1, 2, 50, 'gini'], [5, 2, 48, 'gini'], [18, 100, 48, 'entropy'], [3, 35, 50, 'gini'], [2, 100, 44, 'entropy'], [2, 77, 50, 'entropy'], [2, 80, 50, 'entropy'], [2, 82, 50, 'entropy'], [2, 84, 50, 'entropy'], [2, 86, 50, 'entropy'], [2, 8, 50, 'entropy'], [2, 87, 50, 'entropy'], [2, 89, 50, 'entropy'], [3, 33, 50, 'gini'], [3, 33, 50, 'gini'], [2, 95, 50, 'entropy'], [2, 97, 50, 'entropy'], [2, 53, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 10, 50, 'entropy'], [2, 3, 41, 'entropy'], [3, 33, 50, 'gini'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [16, 2, 47, 'gini'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [3, 33, 50, 'gini'], [3, 36, 50, 'gini'], [3, 32, 50, 'gini'], [2, 100, 44, 'entropy'], [2, 100, 44, 'entropy'], [2, 64, 50, 'entropy'], [2, 47, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 100, 50, 'entropy'], [2, 42, 50, 'entropy'], [2, 56, 50, 'entropy'], [2, 97, 50, 'entropy'], [2, 43, 50, 'entropy'], [2, 37, 50, 'entropy'], [3, 32, 50, 'gini'], [3, 32, 50, 'gini'], [3, 33, 50, 'gini']]]
